# %% [markdown]
# ## This section aims to match up Scopus records and Jstor articles
# If an article's affiliations, citations or abstracts are recorded on Scopus, I want to exclude them from the set of pdf's that are sent to docParser. Matching up the Scopus data is also useful for comparing the textual accuracy of OCR parsers. I use volume, issue, year and page numbers which are common to both the scopus data and the Jstor metadata to match articles.
#
# Then I use a sequence comparison between the journal titles of the matched articles to decide if the scopus data has been matched correctly. If the match ratio is below 70%, the title is investigated and if wrong, the scopus data for that matched article is eihter corrected or discarded. If the scopus data is missing all of affiliations, abstract and citations fields then the match is also discarded.
#
# Finally, if the document type of scopus is different to the classification done during the cleaning section, the article is reclassified according to the Scopus document type.

# %%
import pandas as pd
import numpy as np
from difflib import SequenceMatcher as sq
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import datetime
import pickle

# %%
base_path="/Users/sijiawu/Work/Thesis/Data"

jid=["aer", 'ecta', 'jpe', 'res', 'qje']
cleaned={}

for i in jid:
    # print(i)
    cleaned[i]=pd.read_excel(base_path+'/Processed/'+i.upper()+'_processed.xlsx')
    # print(j_data[i].dtypes)
    cleaned[i]['volume']=cleaned[i]['volume'].astype(int)
    cleaned[i]['year']=cleaned[i]['year'].astype(int)
    cleaned[i]['pages']=cleaned[i]['pages'].str.strip()
    cleaned[i]['number']=cleaned[i]['number'].astype(str).str.strip()
    cleaned[i]=cleaned[i].drop_duplicates(subset=['URL'], keep="last").reset_index(drop=True)
    cleaned[i]['jid']=i


scopus = pd.read_excel(base_path+'/SCOPUS/api_output/scopus_all.xlsx')
cleaned=pd.concat(cleaned.values()).reset_index(drop=True)

# %%
cleaned.journal.unique()
# Out:
# array(['The American Economic Review', 'Econometrica',
#        'Journal of Political Economy', 'The Review of Economic Studies',
#        'The Quarterly Journal of Economics'], dtype=object)

# %%
s_fix=[{'scopus_id': '10.2307/1914237', 'Volume': 46.0, 'Issue': 3},
 {'scopus_id': '10.1086/698748', 'Volume': 126.0, 'Issue': 'S1'},
 {'scopus_id': '10.1086/698750', 'Volume': 126.0, 'Issue': 'S1'},
 {'scopus_id': '10.1086/698749', 'Volume': 126.0, 'Issue': "S1"},
 {'scopus_id': '10.1086/698751', 'Volume': 126.0, 'Issue': 'S1'},
 {'scopus_id': '10.1145/2492002.2482556', 'Volume': 127, 'Issue': 2},
 {'scopus_id': '10.1086/698752', 'Volume': 126.0, 'Issue': "S1"},
 {'scopus_id': '10.1086/698759', 'Volume': 126.0, 'Issue': "S1"},
 {'scopus_id': '10.1086/698760', 'Volume': 126.0, 'Issue': "S1"},
 {'scopus_id': '10.1086/261816', 'Volume': 100, 'Issue': 2},
 {'scopus_id': '10.2307/2295860', 'Volume': 26, 'Issue': 1},
 {'scopus_id': '10.2307/2295857', 'Volume': 26, 'Issue': 1},
 {'scopus_id': '10.2307/2295770', 'Volume': 21, 'Issue': 3},
 {'scopus_id': '10.2307/2296006', 'Volume': 21, 'Issue': 2},
 {'scopus_id': '10.2307/2967659', 'Volume': 4, 'Issue': 1},
 {'scopus_id': '10.2307/2967395', 'Volume': 6, 'Issue': 2},
 {'scopus_id': '10.1093/qje/100.Supplement.823', 'Volume': 100.0, 'Issue': "supplement"},
 {'scopus_id': '10.1093/qje/90.2.344', 'Volume': 89, 'Issue': 4 },
 {'scopus_id': '10.1093/qje/52.Supplement.5', 'Volume': 52.0, 'Issue': "supplement"},
 {'scopus_id': '10.1093/qje/52.Supplement.117', 'Volume': 52.0, 'Issue': "supplement"},
 {'scopus_id': '10.1093/qje/52.Supplement.140', 'Volume': 52.0, 'Issue': 'supplement'},
 {'scopus_id': '10.1093/qje/52.Supplement.9', 'Volume': 52.0, 'Issue': 'supplement'},
 {'scopus_id': '10.2307/2297467', 'Volume': 52.0, 'Issue': '1'},
 {'scopus_id': '10.2307/2297172', 'Volume': 46, 'Issue': '1'},

 {'scopus_id':'10.3982/ECTA17318', 'Title':'CORRIGENDUM TO “TRADING AND INFORMATION DIFFUSION IN OVER-THE-COUNTER MARKETS”'},
 {'scopus_id':'10.3982/ECTA10449', 'Title': 'CORRIGENDUM TO "COMPETING MECHANISMS IN A COMMON VALUE ENVIRONMENT"'},
 {'scopus_id':'10.2307/1914014', "Title":'Estimating the Time Costs of Highway Congestion'},
 {'scopus_id':'10.2307/2171801', 'Title':'individual income, incomplete information, and aggregate consumption'},
 {'scopus_id': '10.2307/1911189', 'Title':'Local Asymptotic Specification Error Analysis'},
 {'scopus_id':'10.2307/1914143','Title':'On the Value of Sample Separation Information'},
 {'scopus_id': '10.2307/2171792', 'Title': 'A Comment on "Learning, Mutation, and Long-Run Equilibria in Games"'},
 {'scopus_id': '10.1111/j.1468-0262.2002.00446.x', "Title": 'Rationalizing Choice Functions by Multiple Rationales'},
 {"Title":'Extending the Classical Normal Errors-in-Variables Model', 'scopus_id': '10.2307/1912823'},
 {"Title":'Several Tests for Model Specification in the Presence of Alternative Hypotheses', 'scopus_id':  '10.2307/1911522'},
 {"Title":'On Seemingly Unrelated Regressions with Error Components','scopus_id':'10.2307/1912824'},
 {"Title":'Approximating a Truncated Normal Regression with the Method of Moments','scopus_id':'10.2307/1912173'},
 {"Title":'Nonlinear Regression on Cross-Section Data' , 'scopus_id':  '10.2307/1913132'},
 {'Title':'PERCEIVED AMBIGUITY AND RELEVANT MEASURES', 'scopus_id': '10.3982/ECTA9872'},
 {'scopus_id':'10.1086/260935','Title':'Uncertainty and Exhaustible Resource Markets'},
{'scopus_id':'10.1086/261170','Title':'Environmental Regulations and Productivity Growth: The Case of Fossil-fueled Electric Power Generation'},
{'scopus_id':'10.1086/261012','Title':'Subsidies to New Energy Sources: Do They Add to Energy Stocks?'},

    {'scopus_id': '10.1086/710554', 'Title': 'erratum: chinese college admissions and school choice reforms: a theoretical analysis'},
    {'scopus_id': '10.1086/703048','Title': 'erratum: the demand for effective charter schools'},
    {'scopus_id': '10.1086/658496', 'Title': 'erratum: measurement error and the relationship between investment and q'},
 {'scopus_id': '10.1086/662074', 'Title': 'erratum: the competitive saving motive: evidence from rising sex ratios and savings rates in china'},
 {'scopus_id': '10.1086/597025', 'Title': 'erratum: moral hazard versus liquidity and optimal unemployment insurance'},
 {'scopus_id': '10.1086/250083', 'Title': 'wages, implicit contracts, and the business cyle: evidence from canadian micro data'},
 {'scopus_id': '10.1086/250041', 'Title': 'new evidence on property tax capitalization'},
  {'scopus_id': '10.1086/523713', 'Title': "erratum: 'the accident externality from driving'"},
  {'scopus_id': '10.1086/500278', 'Title': 'the political economy of corporate control and labor rents'},
   {'scopus_id': '10.1086/317683',  'Title': 'parental benefits from intergenerational coresidence: empirical evidence from rural pakistan'},
   {'scopus_id': '10.1086/317684',  'Title': 'a ricardian model with a continuum of goods under nonhomotheticpreferences: demand complementarities, income distribution, andnorth-south trade'},
   {'scopus_id': '10.1086/338746',  'Title': 'on theories explaining the success of the gravity equation'},
 {'scopus_id': '10.1086/262009',  'Title': "the economics of polygyny in sub-saharan africa: female productivity and the demand for wives in côte d'ivoire"},
 {'scopus_id': '10.1086/261761', 'Title': 'procyclical labor productivity and competing theories of the business cycle: some evidence from interwar u.s. manufacturing industries'},
 {'scopus_id': '10.1086/261869', 'Title': 'trade liberalization and the theory of endogenous protection: an econometric study of u.s. import policy'},
 {'scopus_id': '10.1086/261728', 'Title': 'tax reform and u.s. economic growth'},
 {'scopus_id': '10.1086/261985',
  'Title': 'can imperfect competition explain the difference between primal and dual productivity measures? estimates for u.s. manufacturing'},
  {'scopus_id': '10.1086/260965',
  'Title': 'equalizing discrimination and cartel pricing in transport rate regulation'},
 {'scopus_id': '10.1086/260914',
  'Title': 'completed fertility and its timing'},
 {'scopus_id': '10.1086/260744',
  'Title': 'the transition of land to urban use'},
 {'scopus_id': '10.1086/260864',
  'Title': 'economic losses from forecasting error in agriculture'},
 {'scopus_id': '10.1086/260963',
  'Title': 'interpreting economic time series'},
 {'scopus_id': '10.1086/260737',
  'Title': "an economic basis for the 'national defense argument' for aiding certain industries"},
    {'scopus_id': '10.1086/318605',
  'Title': 'how much did the liberty shipbuilders learn? new evidence for an old case study'},
 {'scopus_id': '10.1086/261107',
  'Title': 'wasteful commuting',
  },
    {'scopus_id':'10.1086/685753','Title':'Erratum: Production versus Revenue Efficiency with Limited Tax Capacity: Theory and Evidence from Pakistan'},


{'scopus_id': '10.1093/restud/rdt002',
  'Title': 'estimating ethnic preferences using ethnic housing quotas in singapore'},
{'scopus_id': '10.1111/1467-937X.00176',
  'Title': 'international trade and currency exchange'},
   {'scopus_id': '10.2307/2297131',
  'Title': 'on sums of production set frontiers'},
   {'scopus_id': '10.2307/2297356',
  'Title': "inefficiency and the demand for 'money' in a sequence economy: a correction"},
  {'scopus_id': '10.2307/2296982',
  'Title': 'more on prices vs. quantities'},

  {'scopus_id': '10.2307/2296360',
  'Title': 'the optimal linear income-tax'},
   {'scopus_id': '10.2307/2296783',
  'Title': 'majority voting and social choice'},
  {'scopus_id': '10.2307/2296504',
  'Title': 'the effect of demand on prices in british manufacturing: another view'},
  {'scopus_id': '10.2307/2296731',
  'Title': '[comment on garegnani]: a reply'},
   
   {'scopus_id': '10.2307/2296621',
  'Title': "[the existence and persistence of cycles in a non-linear model: kaldor's 1940 model re-examined]: a comment"},
  {'scopus_id': '10.2307/2296732',
  'Title': 'expedient choice of transforms in phase-diagramming'} ,
    {'scopus_id': '10.2307/2967562',
  'Title': '[economic theory and socialist economy]: a rejoinder'},
  {'scopus_id': '10.1093/restud/rdz014',
  'Title': 'corrigendum: community enforcement of trust with bounded memory'},
 
{'scopus_id': '10.1093/restud/rds039',
  'Title': 'erratum: endogenous games and mechanisms: side payments among players'},
   {'scopus_id': '10.1111/j.1467-937X.2009.00590.x',
  'Title': 'erratum: sovereign debt without default penalties'},
  {'scopus_id': '10.2307/2298038',
  'Title': 'r&d and economic growth'},
  {'scopus_id': '10.2307/2296610',
  'Title': 'learning by doing and infant industry protection: a partial equilibrium approach'},
  {'scopus_id': '10.2307/2296626',
  'Title': "note on 'the structure of utility functions'"},


{'scopus_id': '10.2307/2296467',
  'Title': 'on experimental research in oligopoly'},
  {'scopus_id': '10.2307/2296435',
  'Title': 'on putty-clay: a comment'},
   {'scopus_id': '10.2307/2974429',
  'Title': 'marginal productivity and the macro-economic theories of distribution: reply to pasinetti and robinson'},
     {'scopus_id': '10.2307/2296246',
  'Title': 'monetary and value theory: comments'},
   {'scopus_id': '10.2307/2295775',
  'Title': '[a note on a point in value and capital]: a reply'},
 {'scopus_id': '10.2307/2295782',
  'Title': '[a futher note on the theory of inflation]: a reply'},
  {'scopus_id': '10.2307/2295776',
  'Title': '[a note on a point in value and capital]: a rejoinder'},
 {'scopus_id': '10.2307/2296228',
  'Title': 'memorandum on the sterling assets of the british colonies: a comment'},
   {'scopus_id': '10.2307/2295778',
  'Title': '[the role of national income estimates in the statistical policy of an underdeveloped area]: a rejoinder'},
   {'scopus_id': '10.2307/2296089',
  'Title': '[a new view of the economics of international readjustment]: a comment'},
   {'scopus_id': '10.2307/2295758',
  'Title': '[community indifference]: a comment'},

{'scopus_id': '10.2307/2967547',
  'Title': 'taxation and production: the wicksell analysis'},

 {'scopus_id': '10.2307/2967621',
  'Title': 'notes on the elasticity of substitution: i'},
 {'scopus_id': '10.2307/2967620',
  'Title': 'taxation and returns: a rejoinder'},
  {'scopus_id': '10.2307/2967530',
  'Title': '[the power of undervalued currency]: a reply'},
 {'scopus_id': '10.2307/2967557',
  'Title': 'a proposal for making monetary management effective in the united states'},
  {'scopus_id': '10.2307/2967506',
  'Title': "further notes on elasticity of substitution: i. note on dr. machlup's article"},
   {'scopus_id': '10.2307/2967660',
  'Title': 'on the economic theory of socialism: part one'},
  {'scopus_id': '10.2307/2295980',
  'Title': "'the economist and the state'--an addendum"},
 
  {'scopus_id': '10.2307/2296572',
  'Title': 'the consumption and the output turnpike theorems in a von neumann type of model--a finite term problem'},
 {'scopus_id': '10.2307/2296247',
  'Title': 'on the invariance of demand for cash and other assets'},
   {'scopus_id': '10.2307/2296545',
  'Title': 'the general instability of a class of competitive growth processes'},
   {'scopus_id': '10.1093/restud/rdt011',
  'Title': 'r&d and productivity: estimating endogenous productivity'},
 {'scopus_id': '10.1111/1467-937X.t01-1-00029',
  'Title': 'strategic delay in a real options model of r&d competition'},
  {"scopus_id":"10.1093/restud/rdv008","Year": "2015"},
  {"scopus_id":"10.1093/restud/rdu039","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu041","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu040","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu045","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv012","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu043","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu037","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv001","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv003","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu036","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu044","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv009","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu025","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv005","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu024","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv006","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv004","Year": "2015"},
{"scopus_id":"10.1093/restud/rdu017","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv011","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv018","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv024","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv017","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv015","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv023","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv020","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv016","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv019","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv025","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv027","Year": "2015"},
{"scopus_id":"10.1093/restud/rdv014","Year": "2015"},
{"scopus_id":"10.1093/restud/rdt038","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt046","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt043","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt041","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt044","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt045","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt035","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt039","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt042","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt036","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt040","Year": "2014"},
{"scopus_id":"10.1093/restud/rdt037","Year": "2014"},
{"scopus_id":"10.2307/2296270","Year": "1951"},
{"scopus_id":"10.2307/2296265","Year": "1951"},
{"scopus_id":"10.2307/2296268","Year": "1951"},
{"scopus_id":"10.2307/2296267","Year": "1951"},
{"scopus_id":"10.2307/2296271","Year": "1951"},
{"scopus_id":"10.2307/2296266","Year": "1951"},
{"scopus_id":"10.2307/2296272","Year": "1951"},
{"scopus_id":"10.2307/2296269","Year": "1951"},
{'scopus_id':'10.2307/2967529','Title':'The Power of Undervalued Currency: A Methodological Comment'},
{'scopus_id':'10.2307/2967420','Title':'[Complementarity and Interrelations of Shifts in Demand]: A Comment'},
{'scopus_id':'10.2307/2295860','Title':"[A Note on Kaldor's `Speculation and Economic Stability']: A Comment"},
{'scopus_id':'10.2307/2296500', 'Title':'the existence of optimal distributed lags'},
  {'scopus_id':'10.2307/2296392', 'Title': "correction to 'on optimal development in a multi-sector economy'"},
{'scopus_id':'10.1093/restud/rdt040','Title':'RETRACTED: Growing up in a Recession'},
     {'scopus_id': '10.2307/1882546',
  'Title': 'positive theory of capital: comments'},
   {'scopus_id': '10.1093/qje/qjx039',
  'Title': "erratum to 'the short-term impact of unconditional cash transfers to the poor: experimental evidence from kenya'"},
 {'scopus_id': '10.1093/qje/qjx025',
  'Title': "erratum to 'field of study, earnings, and self-selection'"},
   {'scopus_id': '10.1093/qje/qjx036',
  'Title': "erratum to 'leveraging lotteries for school value-added: testing and estimation'"},
   {'scopus_id': '10.1093/qje/qjv009',
  'Title': 'erratum: note on proposition 1(a-b) in dal bó, finan and rossi (2013)—strengthening state capabilities: the role of financial incentives in the call to public service, the quarterly'},
   {'scopus_id': '10.1093/qje/qjr047',
  'Title': "erratum: accountability and flexibility in public schools: evidence from boston's charters and pilots"},
  {'scopus_id': '10.1162/0033553042476134',
  'Title': 'erratum: investor protection, optimal incentives, and economic growth'},
   {'scopus_id': '10.2307/2946652',
  'Title': 'corrigendum'},
 {'scopus_id': '10.2307/2937963',
  'Title': 'the dominant-firm advantage in multiproduct industries: evidence from the u. s. airlines'},
   {'scopus_id': '10.2307/1884282',
  'Title': 'the cyclical component of u. s. economic activity'},
 {'scopus_id': '10.2307/1886022',
  'Title': 'adverse selection in the market for slaves: new orleans, 1830-1860'},
   {'scopus_id': '10.2307/1885872',
  'Title': 'the role of knowledge in r&d efficiency'},
   {'scopus_id': '10.2307/1885351',
  'Title': 'choosing new industrial capacity: on-site expansion, branching, and relocation'},





 {'scopus_id': '10.2307/1881983',
  'Title': 'bohm-bawerk on rae'},
 {'scopus_id': '10.2307/1884977',
  'Title': 'final objections to the risk theory of profit: a reply'},
   {'scopus_id': '10.2307/1883669',
  'Title': "'the variation of productive forces': a comment"},
  {'scopus_id': '10.2307/1883305',
  'Title': 'the concept of value: a rejoinder'},
 {'scopus_id': '10.2307/1883561',
  'Title': 'the insurance of bank deposits in the west: ii'},
 {'scopus_id': '10.2307/1883940',
  'Title': 'the sherman act: its design and its effects'},
 {'scopus_id': '10.2307/1883702',
  'Title': 'the monetary theory of the trade cycle and its statistical test cycle and its statistical test',
  },

{'scopus_id': '10.2307/1885821',
  'Title': "'superest ager'"}, 

  {'scopus_id': '10.2307/1883281',
  'Title': 'saving and investment: saving in process analysis'},
 {'scopus_id': '10.2307/1883288',
  'Title': "chamberlin's monopoly supply curve: reply"},
 {'scopus_id': '10.2307/1883282',
  'Title': 'saving and investment: saving and savings'},

{'scopus_id': '10.2307/1882614',
  'Title': "professor knight's capital theory: a reply"},
{'scopus_id': '10.2307/1884071',
  'Title': 'experiments in wheat control: the agricultural adjustment act, 1933'},
 {'scopus_id': '10.2307/1882349',
  'Title': 'the historical emergence of quantity theory: comments'}, 
{'scopus_id': '10.2307/1883552',
  'Title': 'more pitfalls in demand and supply curve analysis: some comments'}, 
{'scopus_id': '10.2307/1884803',
  'Title': 'the yellow dog contract: an explanation'},
 {'scopus_id': '10.2307/1883902',
  'Title': "sombart's die drei nationalökonomien by werner sombart"},
 {'scopus_id': '10.2307/1882966',
  'Title': 'note: the duration of business cycles'},
 {'scopus_id': '10.2307/1882440',
  'Title': "'superest ager'",},
 {'scopus_id': '10.2307/1883945',
  'Title': 'theories of the labor movement, as set forth in recent literature'},
{'scopus_id': '10.2307/1883240',
  'Title': '[notice on international trade, november, 1931]: a correction'},
 {'scopus_id': '10.2307/1883543',
  'Title': 'joint and overhead cost and railway rate policy'},
 {'scopus_id': '10.2307/1883551',
  'Title': 'more pitfalls in demand and supply curve analysis: a final word'},
 {'scopus_id': '10.2307/1883546',
  'Title': 'time series and the derivation of demand and supply curves a study of coffee and tea, 1850-1930'},
 {'scopus_id': '10.2307/1883402',
  'Title': "some remarks on professor hansen's view on technological unemployment: a rejoiner"},


  {'scopus_id': '10.1093/qje/54.4_Part_1.679',
  'Title': 'ad valorem and specific taxes',},
{'scopus_id': '10.2307/1883283',
  'Title': 'saving and investment: final comment'},
 {'scopus_id': '10.2307/1884088',
  'Title': 'professor chamberlin on monopolistic and imperfect competition:reply'},
 {'scopus_id': '10.2307/1882895',
  'Title': 'indemnity payments and gold movements: rejoinder'},
 {'scopus_id': '10.2307/1882894',
  'Title': 'indemnity payments and gold movements: a reply'},
{'scopus_id': '10.2307/1882619',
  'Title': 'german exchange control, 1931-1939: from an emergency measure to a totalitarian institution'},
 {'scopus_id': '10.2307/1883032',
  'Title': 'book review: residential real estate'},
 {'scopus_id': '10.2307/1883341',
  'Title': 'the use of the short-cut graphic method of multiple correlation: further comment'},

{'scopus_id': '10.2307/1885152',
  'Title': 'in defense of monopoly: further comment'},
 {'scopus_id': '10.2307/1882140',
  'Title': 'professor leontief on lord keynes: further comment'},
 {'scopus_id': '10.2307/1880675',
  'Title': 'reparation labor--a preliminary analysis'},
 {'scopus_id': '10.2307/1883474',
  'Title': 'the influence of unionism upon earnings: addendum'},
 {'scopus_id': '10.2307/1885055',
  'Title': 'multiple-plant firms: note on the allocation of output'},
 {'scopus_id': '10.2307/1884830',
  'Title': 'does the consumer benefit from price instability?: further comment'},
{'scopus_id': '10.2307/1880677',
  'Title': "'ability to pay'"},

{'scopus_id': '10.2307/1883259',
  'Title': 'strikes and lock-outs of great britain'},
 {'scopus_id': '10.2307/1884831',
  'Title': 'does the consumer benefit from price instability?: reply'},
{'scopus_id': '10.1093/qje/54.4_Part_1.673',
  'Title': 'the shifting of sales taxes'},

{'scopus_id': '10.2307/1884125',
  'Title': 'real and money wage rates: further comment'},
 {'scopus_id': '10.1093/qje/54.4_Part_1.686',
  'Title': 'ad valorem and specific taxes: rejoinder'},
 {'scopus_id': '10.2307/1883339',
  'Title': 'the scale of agricultural production: rejoinder'},
 {'scopus_id': '10.2307/1884126',
  'Title': 'real and money wage rates: rejoinder'},
 {'scopus_id': '10.2307/1882067',
  'Title': 'the planning approach in public economy: further comment'},
{'scopus_id': '10.2307/1882620',
  'Title': 'the past and future of exchange control'},
  {'scopus_id': '10.2307/1880733',
  'Title': '[peak loads and efficient pricing]: further comment'}, 
{'scopus_id': '10.2307/1880537',
  'Title': '[an optimal unemployment rate: comment]: reply'}, 
{'scopus_id': '10.2307/1882187',
  'Title': 'minimum wages and the long-run elasticity of demand for low-wage labor'},
 {'scopus_id': '10.2307/1880807',
  'Title': '[the consumer does benefit from feasible price stability]: a comment [2]'},
 {'scopus_id': '10.2307/1885931',
  'Title': 'the analysis of revenue sharing in a new approach to collective fiscal decisions'},

 {'scopus_id': '10.2307/1886080',
  'Title': '[alvin h. hansen]: tribute'},
 {'scopus_id': '10.2307/1881802',
  'Title': 'the marginalist principle in a discrete production model under uncetain demand: response'},
 {'scopus_id': '10.2307/1886079',
  'Title': '[alvin h. hansen]: caring for the real problems'},
 {'scopus_id': '10.2307/1886081',
  'Title': '[alvin h. hansen]: some reminiscences'},
 {'scopus_id': '10.2307/1882029',
  'Title': 'foreward'},
{'scopus_id': '10.2307/2936149',
  'Title': 'statistical cost analysis re-revisited: comment'},
 {'scopus_id': '10.2307/1882598',
  'Title': 'reduced forms of rational expectations models'},
 {'scopus_id': '10.2307/1885881',
  'Title': 'two-stage expenditure minimization and some welfare applications'},
  {'scopus_id': '10.2307/1880553',
  'Title': "['the new view of investment']: reply"},
 {'scopus_id': '10.2307/1879331',
  'Title': '[d.h. robertson]: reply'},
 {'scopus_id': '10.2307/1880543',
  'Title': 'the peculiar economics of professional sports: a contribution to the theory of the firm in sporting competition and in market competition'},
 {'scopus_id': '10.2307/1879635',
  'Title': '[credit risk and credit rationing]: reply'},
 {'scopus_id': '10.2307/1883214',
  'Title': 'the commodity structure of world trade: reply'},
 {'scopus_id': '10.2307/1884407',
  'Title': '[real effects of foreign surplus disposal in underdeveloped economies]: further comment'},
 {'scopus_id': '10.2307/1880826',
  'Title': '[steel, administered prices and inflation]: reply'},
 {'scopus_id': '10.2307/1879370',
  'Title': 'regional allocation of investment: an aggregative study in the theory of development programming'},
 {'scopus_id': '10.2307/1879637',
  'Title': '[the stability of growth equilibrium]: reply'},
 {'scopus_id': '10.2307/1880824',
  'Title': '[security and a financial theory of investment]: reply'},
 {'scopus_id': '10.2307/1879634',
  'Title': '[credit risk and credit rationing]: further comment'},
 {'scopus_id': '10.2307/1883212',
  'Title': 'usher and schumpeter on invention, innovation and technological change: reply'},
{'scopus_id': '10.2307/1884198',
  'Title': 'some econometrics of growth: great ratios of economics'},
 {'scopus_id': '10.2307/1885136',
  'Title': 'utility, strategy, and social decision rules: reply'},
 {'scopus_id': '10.2307/1884362',
  'Title': 'structural aspects of monetary velocity: reply'},
 {'scopus_id': '10.2307/1884360',
  'Title': 'state and regional payments mechanisms: reply'},
 {'scopus_id': '10.2307/1883210',
  'Title': 'an economic justification of protectionism: reply'},
{'scopus_id': '10.2307/1882293',
  'Title': 'economic science only--or political economy?'},
 {'scopus_id': '10.2307/1884857',
  'Title': 'the balanced budget: reply'},

{'scopus_id': '10.1093/qje/71.2.324',
  'Title': 'the soviet ural-kuznetsk combine: a study in investment criteria and industrialization policies'},
 {'scopus_id': '10.2307/1884667',
  'Title': 'on the geometry of welfare economics: a suggested diagrammatic treatment of some basic propositions'},
 {'scopus_id': '10.2307/1881924',
  'Title': 'marketing structure and economic development: reply'},

 {'scopus_id': '10.2307/1885855',
  'Title': 'the retarded acceptance of the marginal utility theory: the schumpeter prize fund'},
 {'scopus_id': '10.2307/1882107',
  'Title': 'the economic issues of compulsory health insurance: further comment'},
 {'scopus_id': '10.2307/1884154',
  'Title': 'the multiplier, flexible exchanges, and international: reply'},
 {'scopus_id': '10.2307/1881696',
  'Title': 'profit theory--where do we go from here'},
 {'scopus_id': '10.2307/1885316',
  'Title': 'keynes and the forces of history: reply'},
 {'scopus_id': '10.2307/1879504',
  'Title': 'european unification and the dollar problem: further comment'},
 {'scopus_id': '10.2307/1882225',
  'Title': "the citizen's ephemerides of the physiocrats"},
 {'scopus_id': '10.2307/1879503',
  'Title': 'european unification and the dollar problem: comment'},
 {'scopus_id': '10.2307/1879508',
  'Title': 'clandestine capital movements in balance of payments estimates: reply'},
{'scopus_id': '10.2307/1879540',
  'Title': 'money demand and the interest rate level: reply'}, 
{'scopus_id': '10.2307/1882738',
  'Title': 'reply: proportionality, divisibility, and economies of scale: two comments'},
 {'scopus_id': '10.2307/1884395',
  'Title': "'competitive' output in bilateral monopoly: comment"},
{'scopus_id':'10.2307/1883113',
 'Title':'[The French Economic Situation and the State of Finances]: Correspondence'},
{'scopus_id': '10.2307/1884624',
  'Title': 'railroads: recent books and neglected problems: a correction'},
   {'scopus_id': '10.2307/1879531',
  'Title': 'review of the troops (a chapter from the history of economic analysis)'},

{'scopus_id':'10.2307/1879532',
 'Title':'Distance Inputs and the Space-Economy 1 Part I: The Conceptual Framework'}
 ]

for i in s_fix:
    for j in i.keys():
        if j!='scopus_id':
            scopus.loc[scopus['scopus_id']==i['scopus_id'], j]=i[j]
# Out:
# /var/folders/5b/5mt219qj6l552yrf3l89xgdh0000gn/T/ipykernel_30904/1663697382.py:480: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2015' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   scopus.loc[scopus['scopus_id']==i['scopus_id'], j]=i[j]

# %%
def proc_var(df, field):
    for i in df.index:
        if df.loc[i, field]=='nan':
            df.loc[i, field]=pd.NA
        try:
            df.loc[i, field]=str(int(float(df.loc[i, field])))
        except:
            df.loc[i, field]=str(df.loc[i, field]).strip()

# %%
proc_var(scopus,'Volume')
proc_var(scopus,'Year')
proc_var(scopus,'Issue')
proc_var(scopus,'Page start')
proc_var(scopus,'Page end')
# Out:
# /var/folders/5b/5mt219qj6l552yrf3l89xgdh0000gn/T/ipykernel_30904/2808005286.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, field]=str(int(float(df.loc[i, field])))

# %%
proc_var(cleaned,'year')
proc_var(cleaned, 'pages')
# Out:
# /var/folders/5b/5mt219qj6l552yrf3l89xgdh0000gn/T/ipykernel_30904/2808005286.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, field]=str(int(float(df.loc[i, field])))

# %%
cleaned.head()
# Out:
#                                         issue_url                ISSN  \
# 0  https://www.jstor.org/stable/10.2307/e26966476  00028282, 19447981
# 1  https://www.jstor.org/stable/10.2307/e26966476  00028282, 19447981
# 2  https://www.jstor.org/stable/10.2307/e26966476  00028282, 19447981
# 3  https://www.jstor.org/stable/10.2307/e26966476  00028282, 19447981
# 4  https://www.jstor.org/stable/10.2307/e26966476  00028282, 19447981
#
#                                      URL                       journal number  \
# 0  https://www.jstor.org/stable/26966477  The American Economic Review     12
# 1  https://www.jstor.org/stable/26966478  The American Economic Review     12
# 2  https://www.jstor.org/stable/26966479  The American Economic Review     12
# 3  https://www.jstor.org/stable/26966480  The American Economic Review     12
# 4  https://www.jstor.org/stable/26966481  The American Economic Review     12
#
#                        publisher  \
# 0  American Economic Association
# 1  American Economic Association
# 2  American Economic Association
# 3  American Economic Association
# 4  American Economic Association
#
#                                                title              urldate  \
# 0                                       Front Matter  2023-09-04 00:00:00
# 1  Competition and Entry in Agricultural Markets:...  2023-09-04 00:00:00
# 2         Discounts and Deadlines in Consumer Search  2023-09-04 00:00:00
# 3                    A Model of Competing Narratives  2023-09-04 00:00:00
# 4  A Few Bad Apples Spoil the Barrel: An Anti-Fol...  2023-09-04 00:00:00
#
#    volume  year                                           abstract  \
# 0     110  2020                                                NaN
# 1     110  2020  African agricultural markets are characterized...
# 2     110  2020  We present a new equilibrium search model wher...
# 3     110  2020  We formalize the argument that political disag...
# 4     110  2020  We study anonymous repeated games where player...
#
#                                               author      pages  \
# 0                                                NaN        nan
# 1     Lauren Falcao Bergquist and Michael Dinerstein  3705-3747
# 2  Dominic Coey and Bradley J. Larsen and Brennan...  3748-3785
# 3                        Kfir Eliaz and Ran Spiegler  3786-3816
# 4                Takuo Sugaya and Alexander Wolitzky  3817-3835
#
#   reviewed-author  uploaded  \
# 0             NaN       1.0
# 1             NaN       1.0
# 2             NaN       1.0
# 3             NaN       1.0
# 4             NaN       1.0
#
#                                         author_split title_10 content_type  \
# 0                                                NaN      NaN         MISC
# 1  ['Lauren Falcao Bergquist', 'Michael Dinerstein']      NaN      Article
# 2  ['Dominic Coey', 'Bradley J. Larsen', 'Brennan...      NaN      Article
# 3                     ['Kfir Eliaz', 'Ran Spiegler']      NaN      Article
# 4             ['Takuo Sugaya', 'Alexander Wolitzky']      NaN      Article
#
#   type  jid
# 0    N  aer
# 1    N  aer
# 2    N  aer
# 3    N  aer
# 4    N  aer

# %%
rename_scopus={
 'jid': 'scopus_jid',
 'scopus_id': 'scopus_id',
 'authorgroup': 'scopus_authorgroup',
 'authors': 'scopus_authors',
 'affiliations': 'scopus_affiliations',
 'references': 'scopus_references',
 'Author full names': 'scopus_author_full_names',
 'Title': 'scopus_title',
 'Year': 'scopus_year',
 'Source title': 'scopus_source_title',
 'Volume': 'scopus_volume',
 'Issue': 'scopus_issue',
 'Art. No.': 'scopus_art_no',
 'Page start': 'scopus_page_start',
 'Page end': 'scopus_page_end',
 'Page count': 'scopus_page_end',
 'Cited by': 'scopus_cited_by',
 'DOI': 'scopus_doi',
 'Abstract': 'scopus_abstract',
 'Publisher': 'scopus_publisher',
 'Document Type': 'scopus_document_type',
 'Publication Stage': 'scopus_publication_stage',
 'Open Access': 'scopus_open_access',
 'Source': 'scopus_source',
 'EID': 'scopus_eid'
}

scopus = scopus.rename(columns=rename_scopus)

scopus['scopus_title']=scopus['scopus_title'].str.lower().str.strip().str.replace('‘',"'").str.replace('’',"'").str.replace('"',"'").str.replace('–','-').str.replace('‐','-').str.replace('™','').str.replace('- ','-').str.replace(' -','-').str.replace('“',"'").str.replace("*","").str.replace('”',"'").str.replace('behaviour','behavior').str.strip()
scopus['scopus_title']=scopus['scopus_title'].str.strip().str.split().apply(' '.join).str.strip()
for i in scopus.index:
    if '†' in scopus.loc[i, 'scopus_title']:
        scopus.loc[i, 'scopus_title']=scopus.loc[i, 'scopus_title'].strip()[:-1].strip()
    if scopus.loc[i, 'scopus_title'].strip()[-1]==".":
        scopus.loc[i, 'scopus_title']=scopus.loc[i, 'scopus_title'].strip()[:-1].strip()


cleaned['title']=cleaned['title'].str.lower().str.strip().str.replace('‘',"'").str.replace('’',"'").str.replace('"',"'").str.replace('–','-').str.replace('‐','-').str.replace('™','').str.replace('- ','-').str.replace(' -','-').str.replace('“',"'").str.replace('”',"'").str.replace("*","").str.replace('behaviour','behavior').str.strip()
cleaned['title']=cleaned['title'].str.strip().str.split().apply(' '.join).str.strip()
for i in cleaned.index:
    if '†' in cleaned.loc[i, 'title']:
        cleaned.loc[i, 'title']=cleaned.loc[i, 'title'].strip()[:-1].strip()
    if str(cleaned.loc[i, 'title']).strip()[-1]==".":
        cleaned.loc[i, 'title']=cleaned.loc[i, 'title'].strip()[:-1].strip()

# %%
cleaned.loc[cleaned["number"]==datetime.datetime(2023, 5, 6, 0, 0),'number']='5-6'
cleaned.loc[cleaned["number"]==datetime.datetime(2023, 3, 4, 0, 0),'number']='3-4'
cleaned.loc[cleaned["number"]==datetime.datetime(2023, 1, 2, 0, 0),'number']='1-2'

fix_cleaned=[{"URL":"https://www.jstor.org/stable/40263865", "number":'index'},
{"URL":"https://www.jstor.org/stable/40263866", "number":'index'},
{"URL":"https://www.jstor.org/stable/40263867", "number":'index'},
{"URL":"https://www.jstor.org/stable/1905372", "number":'supplement: guide to econometrica'},
{"URL":"https://www.jstor.org/stable/1905373", "number":'supplement: guide to econometrica'},
{"URL":"https://www.jstor.org/stable/1905374", "number":'supplement: guide to econometrica'},
{"URL":"https://www.jstor.org/stable/1905375", "number":'supplement: guide to econometrica'},
{"URL":"https://www.jstor.org/stable/1905376", "number":'supplement: guide to econometrica'},
{"URL":"https://www.jstor.org/stable/1905377", "number":'supplement: guide to econometrica'},
{"URL":"https://www.jstor.org/stable/1905378", "number":'supplement: guide to econometrica'},
{"URL":"https://www.jstor.org/stable/1905379", "number":'supplement: guide to econometrica'},
{"URL":"https://www.jstor.org/stable/1907284", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907285", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907286", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907287", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907288", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907289", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907290", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907291", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907292", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907293", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907294", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907295", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907296", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907297", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907298", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907299", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907300", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907301", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907302", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907303", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907304", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907305", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907306", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907307", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907308", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907309", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907310", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907311", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907312", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907313", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907314", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907315", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907316", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907317", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907318", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907319", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907320", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907321", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907322", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907323", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907324", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1907325", "number":'supplement: report of the washington meeting'},
{"URL":"https://www.jstor.org/stable/1906934", "number":'supplement'},
{"URL":"https://www.jstor.org/stable/1906935", "number":'supplement'},
{"URL":"https://www.jstor.org/stable/1906936", "number":'supplement'},
{'URL':"https://www.jstor.org/stable/1914237", "title":'Simultaneity in the Birth Rate Equation: The Effects of Education, Labor Force Participation, Income and Health'},

{  'title': 'firm wage differentials and labor market sorting: reconciling theory and evidence',
    'URL': 'https://doi.org/10.1086/695505'},
  {  'title': 'charity and the bequest motive: evidence from seventeenth-century wills',
    'URL': 'https://www.jstor.org/stable/10.1086/317685'},
  { 'title': 'parental benefits from intergenerational coresidence: empirical evidence from rural pakistan',
    'URL': 'https://www.jstor.org/stable/10.1086/317683'},
     {  'title': 'disability insurance benefits and labor supply',
   'URL': 'https://www.jstor.org/stable/10.1086/317682'},
  { 'title': 'redistributing income under proportional representation',
    'URL': 'https://www.jstor.org/stable/10.1086/317680'},
  { 'title': 'in sickness and in health: risk sharing within households in rural ethiopia',
    'URL': 'https://www.jstor.org/stable/10.1086/316098'},
  {  'title': 'are invisible hands good hands? moral hazard, competition, and the second-best in health care markets',
    'URL': 'https://www.jstor.org/stable/10.1086/317672'},
  { 'title': 'risk sharing, sorting, and early contracting',
    'URL': 'https://www.jstor.org/stable/10.1086/317675'},

 { 'title': 'putty-clay and investment: a business cycle analysis',
    'URL': 'https://www.jstor.org/stable/10.1086/317673'},
 {  'title': 'is child labor inefficient?',
    'URL': 'https://www.jstor.org/stable/10.1086/316097'},
 {'title': 'federal mandates by popular demand',
  'URL': 'https://www.jstor.org/stable/10.1086/317669'},
 {'title': 'earnings within education groups and overall productivity growth',
   'URL': 'https://www.jstor.org/stable/10.1086/316101'},
 {'title': 'homework in development economics: household production and the wealth of nations',
   'URL': 'https://www.jstor.org/stable/10.1086/316102'},
 {
  'title': 'age and the quality of work: the case of modern american painters',
  'URL': 'https://www.jstor.org/stable/10.1086/316099'},
 {
  'title': 'an alternative approach to search frictions',
  'URL': 'https://www.jstor.org/stable/10.1086/317674'},
 {
  'title': 'using consumer theory to test competing business cycle models',
  'URL': 'https://www.jstor.org/stable/10.1086/250009'},
   {
  'title': 'induced innovation in american agriculture: a reconsideration',
  'URL': 'https://www.jstor.org/stable/2138675'},
  {'title': 'luxuries are easier to postpone: a proof',
   'URL': 'https://www.jstor.org/stable/10.1086/317668'},
 { 'title': 'balladurette and juppette: a discrete analysis of scrapping subsidies',
   'URL': 'https://www.jstor.org/stable/10.1086/316096'},
 { 'title': 'the making of an oligopoly: firm survival and technological change in the evolution of the u.s. tire industry',
   'URL': 'https://www.jstor.org/stable/10.1086/316100'},
 { 'title': 'equilibrium price dispersion in retail markets for prescription drugs',
    'URL': 'https://www.jstor.org/stable/10.1086/316103'},
 { 'title': 'estimating a bargaining model with asymmetric information: evidence from medical malpractice disputes',
    'URL': 'https://www.jstor.org/stable/10.1086/317677'},
 {'title': 'extensive margins and the demand for money at low interest rates',
    'URL': 'https://www.jstor.org/stable/10.1086/317676'},
 { 'title': 'measurement error and the relationship between investment and q',
   'URL': 'https://www.jstor.org/stable/10.1086/317670'},
 {'title': 'hierarchies and the organization of knowledge in production',
    'URL': 'https://www.jstor.org/stable/10.1086/317671'},
{'URL':'https://www.jstor.org/stable/26550458','title':'The Past, Present, and Future of Economics: A Celebration of the 125-Year Anniversary of the JPE and of Chicago Economics'},
   {
  'title': 'a closed form solution for a model of precautionary saving',
  'URL': 'https://www.jstor.org/stable/2298063'},
  {
  'title': 'optimal population and capital over time: the maximum perspective',
  'URL': 'https://www.jstor.org/stable/2297172'},
  {'URL':'https://www.jstor.org/stable/2967554',
   'title':'notes on the determinateness of the utility function'},
    {  'title': 'notes on the elasticity of substitution: iii.-the elasticity of substitution and the incidence of an imperial inhabited house duty',
  'URL': 'https://www.jstor.org/stable/2967623'},
    {
  'title': 'notes on the elasticity of substitution: i',
  'URL': 'https://www.jstor.org/stable/2967621'},
      {
  'title': 'comment on samuelson and modigliani',
  'URL': 'https://www.jstor.org/stable/2974427'},
   {
  'title': "prices and the turnpike: i. the story of a mare's nest",
  'URL': 'https://www.jstor.org/stable/2295705'},
   {
  'title': "prices and the turnpike: ii. proof of a turnpike theorem: the 'no joint production' case",
  'URL': 'https://www.jstor.org/stable/2295706'},

  {  'title': 'prices and the turnpike: iii. paths of economic growth that are optimal with regard only to final states: a turnpike theorem',
  'URL': 'https://www.jstor.org/stable/2295707'},
{
  'title': 'notes on the determinateness of the utility function: ii',  
  'URL': 'https://www.jstor.org/stable/2967553'},
 {
  'title': "further notes on index numbers: ii. mr. lerner's supplementary limits for price index numbers",
  'URL': 'https://www.jstor.org/stable/2967511'},
 {
  'title': 'further notes on elasticity of substitution: iii. the question of symmetry',
  'URL': 'https://www.jstor.org/stable/2967508'},
 {
  'title': 'further notes on index numbers: i',
  'URL': 'https://www.jstor.org/stable/2967510'},
 {  'title': 'notes on the elasticity of substitution: iv. the elasticity of substitution and the elasticity of demand for one factor of production',
  'URL': 'https://www.jstor.org/stable/2967624'},
 {
  'title': 'notes on the determinateness of the utility function: i',
  'URL': 'https://www.jstor.org/stable/2967552'},
  {
  'title': "further notes on elasticity of substitution: i. note on dr. machlup's article",
  'URL': 'https://www.jstor.org/stable/2967506'},
  {
  'title': 'the chicago plan of banking reform: ii the application of the proposals in england',
  'URL': 'https://www.jstor.org/stable/2967558'},
 {
  'title': 'a symposium on the theory of the forward market: iii. mr. kaldor on the forward market',
  'URL': 'https://www.jstor.org/stable/2967409'},
  {
  'title': 'economic thought in the soviet union: ii.—economic planning and control',
  'URL': 'https://www.jstor.org/stable/2295720'},
{'URL':'https://www.jstor.org/stable/2296392', 'author':'D. Gale'},
 {
  'title': "'the variation of productive forces': a comment",
  'URL': 'https://www.jstor.org/stable/1883669'},

{
  'title': 'on decreasing cost and comparative cost: a rejoinder',
  'URL': 'https://www.jstor.org/stable/1884880'},
{
  'title': 'the positive theory of capital and its critics: iii',
  'URL': 'https://www.jstor.org/stable/1882376'},
{
  'title': 'the social point of view in economics. ii',
  'URL': 'https://www.jstor.org/stable/1883624'},
{
  'title': 'positive contributions of scientific management the elimination of some losses characteristic of present-day manufacture',
  'URL': 'https://www.jstor.org/stable/1885947'},
 {
  'title': 'some fallacies in the interpretation of social costs: a reply',
  'URL': 'https://www.jstor.org/stable/1884879'},
{
  'title': 'chapters on machinery and labor: iv. the introduction of machinery and trade-union policy',
  'URL': 'https://www.jstor.org/stable/1884618'},
   {
  'title': 'toward an understanding of the metropolis: i. some speculations regarding the economic basis of urban concentration',
  'URL': 'https://www.jstor.org/stable/1884617'},

  
 {
  'title': 'sociological elements in economic thought: i. historical',
  'URL': 'https://www.jstor.org/stable/1883862'},

  
{
  'title': 'theories of business fluctuations: i. a classification of the theories',
  'URL': 'https://www.jstor.org/stable/1885554'},
{
  'title': 'rural coöperative credit in china: a record of seven years of experimentation',
  'URL': 'https://www.jstor.org/stable/1883900'},
 {
  'title': 'carrier property consumed in operation and the regulation of profits: a discussion of the i.c.c. report on depreciation',
  'URL': 'https://www.jstor.org/stable/1882471'},

  
 {
  'title': "consumers' surplus in international trade. a supplementary note",
  'URL': 'https://www.jstor.org/stable/1882443'},

  
 {
  'title': 'the interdependence of the price-levels p, p′ and π',
  'URL': 'https://www.jstor.org/stable/1885616'},

  {
  'title': "mr. keynes's consumption function: rejoinder",
  'URL': 'https://www.jstor.org/stable/1885042'},

 {
  'title': 'book review: residential real estate',
  'URL': 'https://www.jstor.org/stable/1883032'},

{
  'title': 'paradoxes in capital theory: a symposium: changes in the rate of profit and switches of techniques',
  'URL': 'https://www.jstor.org/stable/1882911'},
 {
  'title': 'professor hansen and keynesian interest theory: comment',
  'URL': 'https://www.jstor.org/stable/1882002'},

{

 'title':'[The French Economic Situation and the State of Finances]: Correspondence',
 "URL":'https://www.jstor.org/stable/1883113'
},
{
  'title': 'chapters on machinery and labor: i. the introduction of semi-automatic bottle machines',
  'URL': 'https://www.jstor.org/stable/1882432'},
  {
    "title":"chapters on machinery and labor: ii. the introduction of automatic bottle machines",
    "URL":"https://www.jstor.org/stable/1883265"
},

 {
  'title': 'chapters on machinery and labor: iii. machinery and the displacement of skill',
  'URL': 'https://www.jstor.org/stable/1885817'},
]

for i in fix_cleaned:
    for j in i.keys():
        if j!='URL':
            cleaned.loc[cleaned['URL']==i['URL'],j]=i[j]


cleaned['title']=cleaned['title'].str.lower()
scopus['scopus_title']=scopus['scopus_title'].str.lower()

# %%
#discard scopus titles that are post 2020
year_range=[]
for i in range(1940,2021):
    year_range.append(str(i))

ex_years=['2021', '2022', '2023', '2024']

scopus_plus=scopus[(scopus["scopus_year"].isin(ex_years)==True)].reset_index(drop=True)
scopus=scopus[(scopus["scopus_year"].isin(ex_years)==False)].reset_index(drop=True)

# %%
# aer_scopus=scopus[scopus["scopus_jid"]=="aer"].reset_index(drop=True)
# ecta_scopus=scopus[scopus["scopus_jid"]=="ecta"].reset_index(drop=True)
# jpe_scopus=scopus[scopus["scopus_jid"]=="jpe"].reset_index(drop=True)
# res_scopus=scopus[scopus["scopus_jid"]=="res"].reset_index(drop=True)
# qje_scopus=scopus[scopus["scopus_jid"]=="qje"].reset_index(drop=True)

scopus_mis={}

merged=pd.merge(cleaned, scopus, how='left', left_on=['title', 'year', 'jid'], right_on=['scopus_title', 'scopus_year', 'scopus_jid' ])
# Out:
#   journal  total in jstor for period  articles on scopus  \
# 0     aer                      27566                4360
# 1    ecta                       9351                1633
# 2     jpe                      14346                1294
# 3     res                       4157                3037
# 4     qje                       6904                4502
#
#    exact matches on title and year match %  Non-MISC + Non-Rev + post 1940  \
# 0                             4056   93.03                           13389
# 1                             1565   95.84                            5377
# 2                             1266   97.84                            4863
# 3                             2874   94.63                            3281
# 4                             4269   94.82                            3722
#
#    Non-MISC + Non-Rev + post 1940 matches NMR-post-1940 match %  \
# 0                                    4033                 30.12
# 1                                    1554                 28.90
# 2                                    1262                 25.95
# 3                                    2730                 83.21
# 4                                    3042                 81.73
#
#    unmatched scopus articles  unmatched scopus articles post 1940
# 0                        305                                  305
# 1                         69                                   69
# 2                         29                                   29
# 3                        164                                  147
# 4                        234                                  167

# %%
merged["scopus_indicator"]=0

# %%
merged['number'].head()
# Out:
# 0    12
# 1    12
# 2    12
# 3    12
# 4    12
# Name: number, dtype: object

# %%
scopus_recon={}
for l in jid:
    print(l)
    a=0
    ff=[]
    b=0
    check=[]

    for i in scopus_mis[l].index:
        found=0
        max_r=0
        sim=0
        m_sim=0
        target=None
        for j in merged[(merged['year']==scopus_mis[l].loc[i, 'scopus_year'])&(merged['jid']==l)].index:
            
            seq_rat=sq(None, scopus_mis[l].loc[i,'scopus_title'],merged.loc[j, 'title']).ratio()
            fuzz_rat=fuzz.token_sort_ratio(str(scopus_mis[l].loc[i,'scopus_author_full_names']).split('(')[0], str(merged.loc[j,'author']).split(' and ')[0])
            
            if (fuzz_rat>70) & (seq_rat>=sim):
                sim=seq_rat
                m_sim=j
            if (seq_rat>0.95) & (fuzz_rat>95)& (str(scopus_mis[l].loc[i,'scopus_issue'])==str(merged.loc[j,'number'])) & (pd.isna(merged.loc[j,'scopus_id'])==True):
                print("execute")
                if seq_rat>max_r:
                    max_r=seq_rat
                    target=j
                found+=1
                print(found)

                print(scopus_mis[l].loc[i,'scopus_title'])
                print('----match----'+merged.loc[j, 'title']+'    '+str(seq_rat))
                print(scopus_mis[l].loc[i,'scopus_issue']+ '    '+str(merged.loc[j,'number']))
                print(str(scopus_mis[l].loc[i,'scopus_author_full_names']).split('(')[0]+ '    '+str(merged.loc[j,'author']).split(' and ')[0])
                a+=1
                print('\n')
        if found>1:
            ff.append({i:target})
            for k in scopus.columns:
                merged.loc[target,k]=scopus_mis[l].loc[i,k]
        elif found==1:
            print(target)
            for k in scopus.columns:
                merged.loc[target,k]=scopus_mis[l].loc[i,k]
            merged.loc[target, 'scopus_indicator']=1
        else:
            
            if sim!=0:
                print(sim)
                print(str(scopus_mis[l].loc[i,'scopus_author_full_names']).split('(')[0])
                print(str(merged.loc[m_sim, 'author']).split(' and ')[0])
                print(fuzz.token_sort_ratio(str(scopus_mis[l].loc[i,'scopus_author_full_names']).split('(')[0], str(merged.loc[m_sim, 'author']).split(' and ')[0]))
                print(str(scopus_mis[l].loc[i,'scopus_issue']))
                print(str(merged.loc[m_sim,'number']))
                # print(temp.loc[i,'scopus_title'])
                # print(sim)
                # print(m_sim)
                # print('{"scopus_id":"'+temp.loc[i,'scopus_id'] + '", "Title":"'+merged.loc[m_sim, 'title']+'"}')
                check.append({
                    "scopus_id":scopus_mis[l].loc[i,'scopus_id'],
                    "Title":merged.loc[m_sim, 'title'],
                    "scopus_title":scopus_mis[l].loc[i,'scopus_title'],
                    "sim":sim,
                    "as":scopus_mis[l].loc[i,'scopus_author_full_names'],
                    "p":scopus_mis[l].loc[i,'scopus_page_start'],
                    "v":scopus_mis[l].loc[i,'scopus_volume'],
                    "i":scopus_mis[l].loc[i,'scopus_issue'],
                    "a":merged.loc[m_sim, 'author'],
                    "url":merged.loc[m_sim, 'URL'],
                })
                b+=1

    scopus_recon[l]={
        "found_count": a, 
        "check_count": b, 
        "conflict_match": ff, 
        "check": check
        }
# Out:
# aer
# execute
# 1
# does regulatory jurisdiction affect the quality of investment-a dviser regulation?
# ----match----does regulatory jurisdiction affect the quality of investment-adviser regulation?    0.9938650306748467
# 10    10
# Charoenwong, Ben     Ben Charoenwong
#
#
# 179
# execute
# 1
# structural interpretation of vector autoregressions with incomplete identifcation: revisiting the role of oil supply and demand shocks
# ----match----structural interpretation of vector autoregressions with incomplete identification: revisiting the role of oil supply and demand shocks    0.9962825278810409
# 5    5
# Baumeister, Christiane     Christiane Baumeister
#
#
# 243
# execute
# 1
# 'acting wife': marriage market incentives and labor market investments
# ----match----acting wife': marriage market incentives and labor market investments    0.9928057553956835
# 11    11
# Bursztyn, Leonardo     Leonardo Bursztyn
#
#
# 455
# execute
# 1
# the 'pupil' factory: specialization and the production of human capital in school
# ----match----the 'pupil' factory: specialization and the production of human capital in schools    0.9938650306748467
# 3    3
# Fryer, Roland G.     Roland G. Fryer
#
#
# 413
# execute
# 1
# l2-boosting for economic applications
# ----match----l₂-boosting for economic applications    0.972972972972973
# 5    5
# Luo, Ye     Ye Luo
#
#
# 593
# 0.30303030303030304
# Moretti, Enrico
# Enrico Moretti
# 100
# 5
# 7
# execute
# 1
# the mechanism is truthful, why aren't you?
# ----match----the mechanism is truthful, why aren't you 1    0.9647058823529412
# 5    5
# Hassidim, Avinatan     Avinatan Hassidim
#
#
# 583
# 0.4117647058823529
# Duflo, Esther
# Esther Duflo
# 100
# 5
# 5
# execute
# 1
# the great escape?a quantitative evaluation of the fed's liquidity facilities
# ----match----the great escape? a quantitative evaluation of the fed's liquidity facilities    0.9934640522875817
# 3    3
# Negro, Marco Del     Marco Del Negro
#
#
# 694
# execute
# 1
# a context-robust measure of the disincentive cost of unemployment insurance
# ----match----a context-robust measure of the disincentive cost of unemployment lnsurance    0.9866666666666667
# 5    5
# Schmieder, Johannes F.     Johannes F. Schmieder
#
#
# 608
# execute
# 1
# shopping while female: who pays higher prices and why
# ----match----shopping while female: who pays higher prices and why?    0.9906542056074766
# 5    5
# Fitzpatrick, Anne     Anne Fitzpatrick
#
#
# 568
# 0.30303030303030304
# nan
# nan
# 100
# 6
# 9
# execute
# 1
# experiments on decisions under uncertainty:a theoretical framework
# ----match----experiments on decisions under uncertainty: a theoretical framework    0.9924812030075187
# 7    7
# Shmaya, Eran     Eran Shmaya
#
#
# 806
# execute
# 1
# network structure and the aggregation of information:theory and evidence from indonesia
# ----match----network structure and the aggregation of information: theory and evidence from indonesia    0.9942857142857143
# 7    7
# Alatas, Vivi     Vivi Alatas
#
#
# 803
# execute
# 1
# timing decisions in organizations communication and authority in a dynamic environment
# ----match----timing decisions in organizations: communication and authority in a dynamic environment    0.9942196531791907
# 9    9
# Grenadier, Steven R.     Steven R. Grenadier
#
#
# 774
# execute
# 1
# building state capacity: evidence from biometric smartcards in indi
# ----match----building state capacity: evidence from biometric smartcards in india    0.9925925925925926
# 10    10
# Muralidharan, Karthik     Karthik Muralidharan
#
#
# 756
# 0.34146341463414637
# nan
# nan
# 100
# 5
# 8
# execute
# 1
# media influences on social outcomes: the impact of mtv's 16 and pregnant on teen childbearing
# ----match----media influences on social outcomes: the impact of mtv's '16 and pregnant' on teen childbearing    0.9893617021276596
# 12    12
# Kearney, Melissa S.     Melissa S. Kearney
#
#
# 1011
# execute
# 1
# r and d, international sourcing, and the joint impact on firm performance
# ----match----r&d, international sourcing, and the joint impact on firm performance    0.9577464788732394
# 12    12
# Bøler, Esther Ann     Esther Ann Bøler
#
#
# 1014
# 0.6952380952380952
# Head, Allen
# Allen Head
# 100
# 4
# 4
# execute
# 1
# are sticky prices costly?: evidence from the stock market
# ----match----are sticky prices costly? evidence from the stock market    0.9911504424778761
# 1    1
# Gorodnichenko, Yuriy     Yuriy Gorodnichenko
#
#
# 1005
# 0.3373493975903614
# Rousseau, Peter L.
# Peter L. Rousseau
# 100
# 5
# 5
# execute
# 1
# do strict capital requirements raise the cost of capital? bank regulation, capital structure, and the low risk anomaly
# ----match----do strict capital requirements raise the cost of capital? bank regulation, capital structure, and the low-risk anomaly    0.9915254237288136
# 5    5
# Baker, Malcolm     Malcolm Baker
#
#
# 1148
# 0.3614457831325301
# Rousseau, Peter L.
# Peter L. Rousseau
# 100
# 5
# 5
# execute
# 1
# are the nonmonetary costs of energy efficiency investments large? understanding low take up of a free energy efficiency program
# ----match----are the non-monetary costs of energy efficiency investments large? understanding low take-up of a free energy efficiency program    0.9882352941176471
# 5    5
# Fowlie, Meredith     Meredith Fowlie
#
#
# 1126
# 0.2764227642276423
# nan
# nan
# 100
# 5
# 8
# execute
# 1
# income inequality, capitalism, and ethnolinguistic fractionalization
# ----match----income inequality, capitalism, and ethno-linguistic fractionalization    0.9927007299270073
# 5    5
# Sturm, Jan Egbert     Jan-Egbert Sturm
#
#
# 1199
# execute
# 1
# capital and wealth in the twenty first century
# ----match----capital and wealth in the twenty-first century    0.9782608695652174
# 5    5
# Weil, David N.     David N. Weil
#
#
# 1094
# execute
# 1
# deconstructing the energy efficiency gap: conceptual frameworks and evidence
# ----match----deconstructing the energy-efficiency gap: conceptual frameworks and evidence    0.9868421052631579
# 5    5
# Gerarden, Todd     Todd Gerarden
#
#
# 1122
# execute
# 1
# why do firms have purpose? the firm's role as a carrier of identity and reputation
# ----match----why do firms have 'purpose'? the firm's role as a carrier of identity and reputation    0.9879518072289156
# 5    5
# Henderson, Rebecca     Rebecca Henderson
#
#
# 1150
# execute
# 1
# capital taxation in the twenty first century
# ----match----capital taxation in the twenty-first century    0.9772727272727273
# 5    5
# Auerbach, Alan J.     Alan J. Auerbach
#
#
# 1095
# 0.2962962962962963
# Rousseau, Peter L.
# Peter L. Rousseau
# 100
# 5
# 5
# 0.3937007874015748
# Rousseau, Peter L.
# Peter L. Rousseau
# 100
# 5
# 5
# execute
# 1
# academic undermatching of high-achieving minority students: evidence from raceneutral and holistic admissions policies
# ----match----academic undermatching of high-achieving minority students: evidence from race-neutral and holistic admissions policies    0.9957805907172996
# 5    5
# Black, Sandra E.     Sandra E. Black
#
#
# 1201
# execute
# 1
# why don't present biased agents make commitments?
# ----match----why don't present-biased agents make commitments?    0.9795918367346939
# 5    5
# Laibson, David     David Laibson
#
#
# 1139
# execute
# 1
# post selection and post regularization inference in linear models with many controls and instruments
# ----match----post-selection and post-regularization inference in linear models with many controls and instruments    0.98
# 5    5
# Chernozhukov, Victor     Victor Chernozhukov
#
#
# 1181
# execute
# 1
# the long run effect of mexican immigration on crime in us cities: evidence from variation in mexican fertility rates
# ----match----the long-run effect of mexican immigration on crime in us cities: evidence from variation in mexican fertility rates    0.9913793103448276
# 5    5
# Chalfin, Aaron     Aaron Chalfin
#
#
# 1130
# execute
# 1
# secular stagnation: a supply side view
# ----match----secular stagnation: a supply-side view    0.9736842105263158
# 5    5
# Gordon, Robert J.     Robert J. Gordon
#
#
# 1098
# execute
# 1
# bankruptcy rates among nfl players with short lived income spikes
# ----match----bankruptcy rates among nfl players with short-lived income spikes    0.9846153846153847
# 5    5
# Carlson, Kyle     Kyle Carlson
#
#
# 1161
# execute
# 1
# moving up the energy ladder: the effect of an increase in economic well being on the fuel consumption choices of the poor in india
# ----match----moving up the energy ladder: the effect of an increase in economic well-being on the fuel consumption choices of the poor in india    0.9923076923076923
# 5    5
# Hanna, Rema     Rema Hanna
#
#
# 1134
# execute
# 1
# does a bank's history affect its risk taking?
# ----match----does a bank's history affect its risk-taking?    0.9777777777777777
# 5    5
# Bouwman, Christa H. S.     Christa H. S. Bouwman
#
#
# 1149
# execute
# 1
# deciding when to quit: reference dependence over slot machine outcomes
# ----match----deciding when to quit: reference-dependence over slot machine outcomes    0.9857142857142858
# 5    5
# Lien, Jaimie W.     Jaimie W. Lien
#
#
# 1158
# 0.95
# Gregory Mankiw, N.
# N. Gregory Mankiw
# 100
# 5
# 5
# execute
# 1
# measuring voteselling: field evidence from the philippines
# ----match----measuring vote-selling: field evidence from the philippines    0.9914529914529915
# 5    5
# Hicken, Allen     Allen Hicken
#
#
# 1155
# execute
# 1
# about capital in the twenty first century
# ----match----about 'capital in the twenty-first century'    0.9523809523809523
# 5    5
# Piketty, Thomas     Thomas Piketty
#
#
# 1097
# execute
# 1
# satellites, self reports, and submersion: exposure to floods in bangladesh
# ----match----satellites, self-reports, and submersion: exposure to floods in bangladesh    0.9864864864864865
# 5    5
# Guiteras, Raymond     Raymond Guiteras
#
#
# 1132
# execute
# 1
# editors introduction
# ----match----editors' introduction    0.975609756097561
# 5    5
# Johnson, William R.     William R. Johnson
#
#
# 1092
# execute
# 1
# informal employment in a growing and globalizing low income country
# ----match----informal employment in a growing and globalizing low-income country    0.9850746268656716
# 5    5
# McCaig, Brian     Brian McCaig
#
#
# 1191
# execute
# 1
# evaluating econometric evaluations of post secondary aid
# ----match----evaluating econometric evaluations of post-secondary aid    0.9821428571428571
# 5    5
# Angrist, Josh     Josh Angrist
#
#
# 1184
# execute
# 1
# loss aversion in post sale purchases of consumer products and their substitutes
# ----match----loss aversion in post-sale purchases of consumer products and their substitutes    0.9873417721518988
# 5    5
# Ray, Debajyoti     Debajyoti Ray
#
#
# 1160
# execute
# 1
# the effect of extended unemployment insurance benefits: evidence from the 2012-2013 phase out
# ----match----the effect of extended unemployment insurance benefits: evidence from the 2012-2013 phase-out    0.989247311827957
# 5    5
# Farber, Henry S.     Henry S. Farber
#
#
# 1120
# execute
# 1
# what high achieving low income students know about college
# ----match----what high-achieving low-income students know about college    0.9655172413793104
# 5    5
# Hoxby, Caroline M.     Caroline M. Hoxby
#
#
# 1186
# 0.2926829268292683
# nan
# nan
# 100
# 5
# 8
# execute
# 1
# revealed (p)reference theory
# ----match----revealed (p) reference theory    0.9824561403508771
# 1    1
# Ok, Efe A.     Efe A. Ok
#
#
# 1268
# execute
# 1
# mandatory versus discretionary spending: the status quo effect
# ----match----mandatory versus discretionary spending: the status quo effecf    0.9838709677419355
# 10    10
# Bowen, T. Renee     T. Renee Bowen
#
#
# 1308
# execute
# 1
# present bias and collective dynamic choice in the lab?
# ----match----present bias and collective dynamic choice in the lab    0.9906542056074766
# 12    12
# Jackson, Matthew O.     Matthew O. Jackson
#
#
# 1287
# execute
# 1
# reputation and persistence of adverse selection in secondary loan markets?
# ----match----reputation and persistence of adverse selection in secondary loan markets    0.9931972789115646
# 12    12
# Chari, V.V.     V. V. Chari
#
#
# 1283
# execute
# 1
# hospital choices, hospital prices, and financial incentives to physicians?
# ----match----hospital choices, hospital prices, and financial incentives to physicians    0.9931972789115646
# 12    12
# Ho, Kate     Kate Ho
#
#
# 1278
# 0.9166666666666666
# Rahman, David
# David Rahman
# 100
# 11
# 11
# execute
# 1
# the effects of poor neonatal health on children's cognitive development?
# ----match----the effects of poor neonatal health on children's cognitive development    0.993006993006993
# 12    12
# Figlio, David     David Figlio
#
#
# 1280
# execute
# 1
# consumption and debt response to unanticipated income shocks: evidence from a natural experiment in singapore?
# ----match----consumption and debt response to unanticipated income shocks: evidence from a natural experiment in singapore    0.9954337899543378
# 12    12
# Agarwal, Sumit     Sumit Agarwal
#
#
# 1288
# execute
# 1
# trade wars and trade talks with data?
# ----match----trade wars and trade talks with data    0.9863013698630136
# 12    12
# Ossa, Ralph     Ralph Ossa
#
#
# 1285
# execute
# 1
# the costs and consequences of clean air act regulation of co2 from power plants
# ----match----the costs and consequences of clean air act regulation of co₂ from power plants    0.9873417721518988
# 5    5
# Burtraw, Dallas     Dallas Burtraw
#
#
# 1482
# execute
# 1
# the economics of predation: what drives pricing when there is learning-by-doing
# ----match----the economics of predation: what drives pricing when there is learning-by-doing?    0.9937106918238994
# 3    3
# Besanko, David     David Besanko
#
#
# 1513
# execute
# 1
# do prices and attributes explain international differences in food purchases
# ----match----do prices and attributes explain international differences in food purchases?    0.9934640522875817
# 3    3
# Dubois, Pierre     Pierre Dubois
#
#
# 1512
# 0.7796610169491526
# Cummins, Jason G.
# Jason G. Cummins
# 100
# 4
# 4
# 0.9948717948717949
# Hout, Michael
# Michael Hout
# 100
# 5
# 5
# execute
# 1
# family, education, and sources of wealth among the richest americans, 1982-2012
# ----match----family, education, and sources of wealth among the richest americans, 1982—2012    0.9873417721518988
# 3    3
# Kaplan, Steven N.     Steven N. Kaplan
#
#
# 1664
# execute
# 1
# effects of job corps training on wages of adolescents and young adults
# ----match----the effects of job corps training on wages of adolescents and young adults    0.9722222222222222
# 3    3
# Blanco, German     German Blanco
#
#
# 1711
# execute
# 1
# married to intolerance: attitudes toward intermarriage in germany, 1900-2006
# ----match----married to intolerance: attitudes toward intermarriage in germany, 1900—2006    0.9868421052631579
# 3    3
# Voigtländer, Nico     Nico Voigtländer
#
#
# 1650
# execute
# 1
# not just the great contraction: friedman and schwartz's a monetary history of the united states 1867 to 1960
# ----match----not just the great contraction: friedman and schwartz's 'a monetary history of the united states 1867 to 1960'    0.9908256880733946
# 3    3
# Bordo, Michael D.     Michael D. Bordo
#
#
# 1647
# execute
# 1
# income inequality, mobility, and turnover at the top in the us, 1987-2010
# ----match----income inequality, mobility, and turnover at the top in the us, 1987—2010    0.9863013698630136
# 3    3
# Auten, Gerald     Gerald Auten
#
#
# 1666
# execute
# 1
# physician agency and adoption of generic pharmaceuticals
# ----match----physician agency and adoption of generic pharmaceutical    0.990990990990991
# 6    6
# Iizuka, Toshiaki     Toshiaki Iizuka
#
#
# 1845
# execute
# 1
# is the volatility of the market price of risk due to intermittent portfolio rebalancing
# ----match----is the volatility of the market price of risk due to intermittent portfolio rebalancing?    0.9942857142857143
# 6    6
# Chien, Yili     YiLi Chien
#
#
# 1846
# execute
# 1
# but who will monitor the monitor
# ----match----but who will monitor the monitor?    0.9846153846153847
# 6    6
# Rahman, David     David Rahman
#
#
# 1843
# execute
# 1
# access to credit by small businesses: how relevant are race, ethnicity, and gender
# ----match----access to credit by small businesses: how relevant are race, ethnicity, and gender?    0.9939393939393939
# 3    3
# Asiedu, Elizabeth     Elizabeth Asiedu
#
#
# 1997
# execute
# 1
# limited-purpose banking-moving from 'trust me' to 'show me' banking
# ----match----limited-purpose banking—moving from 'trust me' to 'show me' banking    0.9850746268656716
# 3    3
# Chamley, Christophe     Christophe Chamley
#
#
# 1923
# execute
# 1
# unemployment in the great recession: did the housing market crisis prevent the unemployed from moving to take jobs
# ----match----unemployment in the great recession: did the housing market crisis prevent the unemployed from moving to take jobs?    0.9956331877729258
# 3    3
# Farber, Henry S.     Henry S. Farber
#
#
# 1995
# execute
# 1
# coming to america: does having a developed home country matter for self-employment in the united states
# ----match----coming to america: does having a developed home country matter for self-employment in the united states?    0.9951690821256038
# 3    3
# Oyelere, Ruth Uwaifo     Ruth Uwaifo Oyelere
#
#
# 1998
# 0.38016528925619836
# Autor, David
# David Card
# 76
# 3
# 6
# execute
# 1
# how did health care reform in massachusetts impact insurance premiums
# ----match----how did health care reform in massachusetts impact insurance premiums?    0.9928057553956835
# 3    3
# Graves, John A.     John A. Graves
#
#
# 1993
# execute
# 1
# heterogeneity in neighborhood-level price growth in the united states, 1993-2009
# ----match----heterogeneity in neighborhood-level price growth in the united states, 1993—2009    0.9875
# 3    3
# Ferreira, Fernando     Fernando Ferreira
#
#
# 1926
# execute
# 1
# did the housing price bubble clobber local labor market job and worker flows when it burst
# ----match----did the housing price bubble clobber local labor market job and worker flows when it burst?    0.994475138121547
# 3    3
# Abowd, John M.     John M. Abowd
#
#
# 2008
# 0.34210526315789475
# Davis, Steven J.
# Steven J. Davis
# 100
# 3
# 3
# 0.3076923076923077
# Duflo, Esther
# Esther Duflo
# 100
# 3
# 4
# execute
# 1
# credit booms gone bust: monetary policy, leverage cycles, and financial crises, 1870-2008
# ----match----credit booms gone bust: monetary policy, leverage cycles, and financial crises, 1870-—2008    0.994413407821229
# 2    2
# Schularick, Moritz     Moritz Schularick
#
#
# 2030
# 0.6802721088435374
# Jermann, Urban
# Urban Jermann
# 100
# 2
# 2
# 0.2127659574468085
# Woodford, Michael
# Michael Woodford
# 100
# 3
# 3
# 0.7565543071161048
# Apesteguia, Jose
# Jose Apesteguia
# 100
# 4
# 4
# execute
# 1
# house prices, home equity-based borrowing, and the us household leverage crisis
# ----match----house prices, home equity—based borrowing, and the us household leverage crisis    0.9873417721518988
# 5    5
# Mian, Atif     Atif Mian
#
#
# 2128
# execute
# 1
# trends in quality-adjusted skill premia in the united states, 1960-2000
# ----match----trends in quality-adjusted skill premia in the united states, 1960—2000    0.9859154929577465
# 6    6
# Carneiro, Pedro     Pedro Carneiro
#
#
# 2092
# 0.6176470588235294
# Johnson, William R.
# William R. Johnson
# 100
# 3
# 3
# 0.38095238095238093
# Ashenfelter, Orley C.
# Orley C. Ashenfelter
# 100
# 3
# 3
# 0.8840579710144928
# Stock, Wendy A.
# Wendy A. Stock
# 100
# 3
# 3
# execute
# 1
# the willingness to pay-willingness to accept gap, the 'endowment effect,' subject misconceptions, and experimental procedures for eliciting valuations: comment
# ----match----the willingness to pay—willingness to accept gap, the 'endowment effect,' subject misconceptions, and experimental procedures for eliciting valuations: comment    0.9937106918238994
# 2    2
# Isoni, Andrea     Andrea Isoni
#
#
# 2307
# execute
# 1
# contracts as reference points-experimental evidence
# ----match----contracts as reference points—experimental evidence    0.9803921568627451
# 2    2
# Fehr, Ernst     Ernst Fehr
#
#
# 2290
# execute
# 1
# efficiency gains from team-based coordination-large-scale experimental evidence
# ----match----efficiency gains from team-based coordination—large-scale experimental evidence    0.9873417721518988
# 4    4
# Feri, Francesco     Francesco Feri
#
#
# 2384
# execute
# 1
# watta satta: bride exchange and women's welfare in rural pakistan
# ----match----'watta satta': bride exchange and women's welfare in rural pakistan    0.9848484848484849
# 4    4
# Jacoby, Hanan G.     Hanan G. Jacoby
#
#
# 2379
# 0.45161290322580644
# Moffitt, Robert A.
# Robert A. Margo
# 73
# 1
# 1
# execute
# 1
# the willingness to pay-willingness to accept gap, the 'endowment effect,' subject misconceptions, and experimental procedures for eliciting valuations: reply
# ----match----the willingness to pay—willingness to accept gap, the 'endowment effect,' subject misconceptions, and experimental procedures for eliciting valuations: reply    0.9936305732484076
# 2    2
# Plott, Charles R.     Charles R. Plott
#
#
# 2308
# execute
# 1
# the economic history of the american economic review: a century's explosion of economics research
# ----match----the economic history of the 'american economic review': a century's explosion of economics research    0.9897959183673469
# 1    1
# Margo, Robert A.     Robert A. Margo
#
#
# 2315
# 0.8021978021978022
# Basker, Emek
# Emek Basker
# 100
# 2
# 2
# 0.21176470588235294
# Chiteji, Ngina
# Ngina Chiteji
# 100
# 2
# 2
# 0.8089887640449438
# Mason, Patrick L.
# Patrick L. Mason
# 100
# 2
# 2
# execute
# 1
# emissions trading, electricity restructuring, and investment in pollution abatement
# ----match----emissions trading, electricity restructing, and investment in pollution abatement    0.9878048780487805
# 3    3
# Fowlie, Meredith     Meredith Fowlie
#
#
# 2396
# 0.38095238095238093
# Hall, Robert E.
# Robert E. Hall
# 100
# 2
# 2
# 0.9433962264150944
# nan
# nan
# 100
# 3
# 3
# 0.6451612903225806
# Chan, David
# David Chan
# 100
# 2
# 2
# 0.95
# Uhlig, Harald
# Harald Uhlig
# 100
# 2
# 2
# execute
# 1
# the business cycle in a changing economy: conceptualization, measurement, dating
# ----match----the business cycle in changing economy: conceptualization, measurement, dating    0.9873417721518988
# 2    2
# Sinai, Allen     Allen Sinai
#
#
# 2425
# execute
# 1
# long run risk, the wealth-consumption ratio,and the temporal pricing of risk
# ----match----long run risk, the wealth-consumption ratio, and the temporal pricing of risk    0.9934640522875817
# 2    2
# Koijen, Ralph S.J.     Ralph S.J. Koijen
#
#
# 2525
# execute
# 1
# surprised by the parimutuel odds?
# ----match----suprised by the parimutuel odds?    0.9846153846153847
# 5    5
# Ottaviani, Marco     Marco Ottaviani
#
#
# 2594
# execute
# 1
# intergroup confict and intra-group punishment in an experimental contest game
# ----match----intergroup conflict and intra-group punishment in an experimental contest game    0.9935483870967742
# 1    1
# Abbink, Klaus     Klaus Abbink
#
#
# 2558
# 0.8187134502923976
# Hadsell, Lester
# Lester Hadsell
# 100
# 2
# 2
# 0.25
# Watts, Michael
# Michael E. Waugh
# 71
# 2
# 5
# execute
# 1
# wage subsidies for micro enterprises
# ----match----wage subsidies for microenterprises    0.9859154929577465
# 2    2
# De Mel, Suresh     Suresh de Mel
#
#
# 2536
# 0.6176470588235294
# Johnson, William R.
# William R. Johnson
# 100
# 2
# 2
# execute
# 1
# the public and private sectors in the process of innovation:theory and evidence from the mouse genetics revolution
# ----match----the public and private sectors in the process of innovation: theory and evidence from the mouse genetics revolution    0.9956331877729258
# 2    2
# Aghion, Philippe     Philippe Aghion
#
#
# 2449
# 0.10810810810810811
# Postlewaite, Andrew
# Andrew Foster
# 71
# 2
# 2
# 0.3448275862068966
# Abraham, Katharine
# Katharine G. Abraham
# 94
# 2
# 2
# 0.6407766990291263
# Edlund, Lena
# Lena Edlund
# 100
# 3
# 3
# 0.3058823529411765
# Auerbach, Alan J.
# Alan J. Auerbach
# 100
# 2
# 2
# 0.38095238095238093
# Deaton, Angus
# Angus Deaton
# 100
# 2
# 2
# 0.6176470588235294
# Johnson, William R.
# William R. Johnson
# 100
# 2
# 2
# 0.9019607843137255
# Colander, David
# David Colander
# 100
# 2
# 2
# 0.6666666666666666
# Ricardo, Alonso
# Ricardo Alonso
# 100
# 3
# 3
# execute
# 1
# stationary concepts for experimental 2x×2-games
# ----match----stationary concepts for experimental 2×2-games    0.989247311827957
# 3    3
# Selten, Reinhard     Reinhard Selten
#
#
# 2863
# execute
# 1
# editors' introduction
# ----match----editor's introduction    0.9523809523809523
# 2    2
# Johnson, William R.     William R. Johnson
#
#
# 2880
# execute
# 1
# an equilibrium model of global imbalances and low interest rates
# ----match----an equilibrium model of 'global imbalances' and low interest rates    0.9846153846153847
# 1    1
# Caballero, Ricardo J.     Ricardo J. Caballero
#
#
# 2989
# execute
# 1
# on the cyclically of research and development
# ----match----on the cyclicality of research and development    0.967032967032967
# 4    4
# Barlevy, Gadi     Gadi Barlevy
#
#
# 3034
# execute
# 1
# experimental testing of intrinsic preferences for noninstrumental information
# ----match----experimental testing of intrinsic preferences for nonlnstrumental information    0.987012987012987
# 2    2
# Eliaz, Kfir     Kfir Eliaz
#
#
# 3109
# execute
# 1
# aid effectiveness-opening the black box
# ----match----aid effectiveness: opening the black box    0.9620253164556962
# 2    2
# Bourguignon, François     François Bourguignon
#
#
# 3137
# execute
# 1
# systemic liquidity in the federal funds market
# ----match----systemic illiquidity in the federal funds market    0.9787234042553191
# 2    2
# Ashcraft, Adam B.     Adam B. Ashcraft
#
#
# 3119
# execute
# 1
# a change would do you good ... an experimental study on how to overcome coordination failure in organizations
# ----match----a change would do you good .... an experimental study on how to overcome coordination failure in organizations    0.9954337899543378
# 3    3
# Brandts, Jordi     Jordi Brandts
#
#
# 3279
# 0.5673758865248227
# Fershtman, Chaim
# Chaim Fershtman
# 100
# 4
# 4
# 0.6390532544378699
# Mankiw, N. Gregory
# N. Gregory Mankiw
# 100
# 5
# 5
# 0.6428571428571429
# Grossman, Gene M.
# Gene M. Grossman
# 100
# 1
# 1
# execute
# 1
# the new york times and the market for local newspapers
# ----match----the 'new york times' and the market for local newspapers    0.9818181818181818
# 1    1
# George, Lisa M.     Lisa M. George
#
#
# 3411
# execute
# 1
# state 'currencies' and the transition to the u.s. dollar: reply-including a new view from canada
# ----match----state 'currencies' and the transition to the u.s. dollar: reply: including a new view from canada    0.9844559585492227
# 4    4
# Grubb, Farley W.     Farley W. Grubb
#
#
# 3467
# execute
# 1
# a group rule-utilitarian approach to voter turnout: theory and evidence
# ----match----a group rule: utilitarian approach to voter turnout: theory and evidence    0.9790209790209791
# 5    5
# Coate, Stephen     Stephen Coate
#
#
# 3628
# execute
# 1
# social comparisons and pro-social behavior: testing conditional cooperation in a field experiment
# ----match----social comparisons and pro-social behavior: testing 'conditional cooperation' in a field experiment    0.9897959183673469
# 5    5
# Frey, Bruno S.     Bruno S. Frey
#
#
# 3640
# execute
# 1
# pareto-lmproving campaign finance policy
# ----match----pareto-improving campaign finance policy    0.975
# 3    3
# Coate, Stephen     Stephen Coate
#
#
# 3682
# 0.8846153846153846
# Shachar, Ron
# Ron Shachar
# 100
# 1
# 1
# execute
# 1
# is aggregation a problem for sovereign debt restructuring
# ----match----is aggregation a problem for sovereign debt restructuring?    0.991304347826087
# 2    2
# Eichengreen, Barry     Barry Eichengreen
#
#
# 3908
# execute
# 1
# employer stock and 401 (k) plans
# ----match----employer stock and 401(k) plans    0.9841269841269841
# 2    2
# Poterba, James M.     James M. Poterba
#
#
# 3965
# execute
# 1
# portfolio choice and trading in a large 401 (k) plan
# ----match----portfolio choice and trading in a large 401(k) plan    0.9902912621359223
# 1    1
# Agnew, Julie     Julie Agnew
#
#
# 3989
# execute
# 1
# the fed and interest rates-a high-frequency identification
# ----match----the fed and interest rates: a high-frequency identification    0.9743589743589743
# 2    2
# Cochrane, John H.     John H. Cochrane
#
#
# 4118
# execute
# 1
# wealth: asset-accumulation differences by race-scf data, 1995 and 1998
# ----match----wealth: asset-accumulation differences by race: scf data, 1995 and 1998    0.9787234042553191
# 2    2
# Straight, Ronald L.     Ronald L. Straight
#
#
# 4161
# 0.5753424657534246
# Findlay, Ronald
# Ronald Findlay
# 100
# 2
# 2
# 0.8670520231213873
# Heckman, James J.
# James J. Heckman
# 100
# 2
# 2
# 0.8615384615384616
# Gruber, Jonathan
# Jonathan Gruber
# 100
# 2
# 2
# 0.7528089887640449
# De La Fuente, Angel
# Angel de la Fuente
# 100
# 2
# 2
# 0.7487179487179487
# Whinston, Michael D.
# Michael D. Whinston
# 100
# 2
# 2
# 0.6105263157894737
# Bernanke, Ben S.
# Ben S. Bernanke
# 100
# 2
# 2
# 0.7857142857142857
# Argys, Laura M.
# Laura M. Argys
# 100
# 2
# 2
# 0.375
# Barro, Robert J.
# Robert J. Barro
# 100
# 2
# 2
# 0.36363636363636365
# Laffont, Jean-Jacques
# Jean-Jacques Laffont
# 100
# 2
# 2
# 0.8617886178861789
# Broda, Christian
# Christian Broda
# 100
# 2
# 2
# 0.7337278106508875
# Allayannis, George
# George Allayannis
# 100
# 2
# 2
# 0.8622222222222222
# Berndt, Ernst R.
# Ernst R. Berndt
# 100
# 2
# 2
# 0.700507614213198
# Peoples Jr., James
# James Peoples
# 90
# 2
# 2
# 0.8266666666666667
# Athey, Susan
# Susan Athey
# 100
# 2
# 2
# 0.7777777777777778
# Manski, Charles F.
# Charles F. Manski
# 100
# 2
# 2
# 0.7735849056603774
# Hall, Robert E.
# Robert E. Hall
# 100
# 2
# 2
# 0.7428571428571429
# Salemi, Michael K.
# Michael K. Salemi
# 100
# 2
# 2
# 0.8067226890756303
# Gourinchas, Pierre-Olivier
# Pierre-Olivier Gourinchas
# 100
# 2
# 2
# 0.6578947368421053
# Hirshleifer, Jack
# Jack Hirshleifer
# 100
# 2
# 2
# 0.5899280575539568
# Bond, Eric W.
# Eric W. Bond
# 100
# 2
# 2
# 0.5714285714285714
# Alvarez, Fernando
# Fernando Alvarez
# 100
# 2
# 2
# 0.48214285714285715
# Dornbusch, Rudi
# Rudi Dornbusch
# 100
# 2
# 2
# 0.7717391304347826
# Chay, Kenneth Y.
# Kenneth Y. Chay
# 100
# 2
# 2
# 0.6461538461538462
# Darity Jr., William
# William Darity
# 90
# 2
# 2
# 0.7931034482758621
# Rose, Nancy L.
# Nancy L. Rose
# 100
# 2
# 2
# 0.49411764705882355
# Jorgenson, Dale W.
# Dale W. Jorgenson
# 100
# 2
# 2
# 0.6883116883116883
# Acemoglu, Daron
# Daron Acemoglu
# 100
# 2
# 2
# 0.8165680473372781
# Bertrand, Marianne
# Marianne Bertrand
# 100
# 2
# 2
# execute
# 1
# economies of scale and constant returns to capital:a neglected early contribution to the theory of economic growth
# ----match----economies of scale and constant returns to capital: a neglected early contribution to the theory of economic growth    0.9956331877729258
# 1    1
# Cannon, Edmund S.     Edmund S. Cannon
#
#
# 4614
# 0.7123287671232876
# Baily, Martin Neil
# Martin Neil Baily
# 100
# 2
# 2
# 0.8487394957983193
# Calvo, Guillermo A.
# Guillermo A. Calvo
# 100
# 2
# 2
# 0.7747747747747747
# LeBaron, Blake
# Blake LeBaron
# 100
# 2
# 2
# 0.7739463601532567
# Carroll, Christopher D.
# Christopher D. Carroll
# 100
# 2
# 2
# execute
# 1
# demand reduction in multiunit auctions:evidence from a sportscard field experiment
# ----match----demand reduction in multiunit auctions: evidence from a sportscard field experiment    0.9939393939393939
# 4    4
# List, John A.     John A. List
#
#
# 4460
# 0.7096774193548387
# Colander, David
# David Colander
# 100
# 2
# 2
# 0.8531468531468531
# Svensson, Lars E. O.
# Lars E. O. Svensson
# 100
# 2
# 2
# 0.8057553956834532
# Lee, Ronald
# Ronald Lee
# 100
# 2
# 2
# 0.6296296296296297
# Bernheim, B. Douglas
# B. Douglas Bernheim
# 100
# 2
# 2
# 0.7142857142857143
# Boskin, Michael J.
# Michael J. Boskin
# 100
# 2
# 2
# execute
# 1
# habit formation in consumption and its implicationsfor monetary-policy models
# ----match----habit formation in consumption and its implications for monetary-policy models    0.9935483870967742
# 3    3
# Fuhrer, Jeffrey C.     Jeffrey C. Fuhrer
#
#
# 4477
# 0.7313432835820896
# Loewenstein, George
# George Loewenstein
# 100
# 2
# 2
# 0.8796296296296297
# Duflo, Esther
# Esther Duflo
# 100
# 2
# 2
# 0.5185185185185185
# Desai, Padma
# Padma Desai
# 100
# 2
# 2
# 0.7835051546391752
# Jensen, Elizabeth J.
# Elizabeth J. Jensen
# 100
# 2
# 2
# execute
# 1
# international trade as an 'integrated equilibrium':new perspectives
# ----match----international trade as an 'integrated equilibrium': new perspectives    0.9925925925925926
# 2    2
# Davis, Donald R.     Donald R. Davis
#
#
# 4530
# 0.691358024691358
# Moffitt, Robert A.
# Robert A. Moffitt
# 100
# 2
# 2
# 0.7672955974842768
# Trefler, Daniel
# Daniel Trefler
# 100
# 2
# 2
# 0.8356164383561644
# Summers, Lawrence H.
# Lawrence H. Summers
# 100
# 2
# 2
# 0.7272727272727273
# Welch, Finis
# Finis Welch
# 100
# 2
# 2
# 0.8736842105263158
# Calcott, Paul
# Paul Calcott
# 100
# 2
# 2
# execute
# 1
# emergence of money as a medium of exchange:an experimental study
# ----match----emergence of money as a medium of exchange: an experimental study    0.9922480620155039
# 4    4
# Duffy, John     John Duffy
#
#
# 4655
# 0.8859060402684564
# Feenberg, Daniel R.
# Daniel R. Feenberg
# 100
# 2
# 2
# 0.5182724252491694
# Jaffe, Adam B.
# Adam B. Jaffe
# 100
# 2
# 2
# execute
# 1
# the reaction of household consumption to predictablechanges in social security taxes
# ----match----the reaction of household consumption to predictable changes in social security taxes    0.9940828402366864
# 4    4
# Parker, Jonathan A.     Jonathan A. Parker
#
#
# 4660
# execute
# 1
# commodity taxes under fiscal competition:stackelberg equilibrium and optimality
# ----match----commodity taxes under fiscal competition: stackelberg equilibrium and optimality    0.9937106918238994
# 4    4
# Wang, You-Qiang     You-Qiang Wang
#
#
# 4661
# ecta
# 0.460431654676259
# nan
# nan
# 100
# 1
# 4
# 0.6917293233082706
# nan
# nan
# 100
# 1
# 1
# 0.48854961832061067
# nan
# nan
# 100
# 1
# 4
# 0.4172661870503597
# nan
# nan
# 100
# 1
# 4
# 0.5228758169934641
# nan
# nan
# 100
# 1
# 4
# execute
# 1
# engel's law in the global economy: demand-induced patterns of structural change, innovation, and trade
# ----match----engels law in the global economy: demand-induced patterns of structural change, innovation, and trade    0.9950738916256158
# 2    2
# Matsuyama, Kiminori     Kiminori Matsuyama
#
#
# 27746
# 0.6766917293233082
# nan
# nan
# 100
# 1
# 1
# 0.44274809160305345
# nan
# nan
# 100
# 1
# 4
# 0.460431654676259
# nan
# nan
# 100
# 1
# 1
# 0.4172661870503597
# nan
# nan
# 100
# 1
# 1
# 0.44274809160305345
# nan
# nan
# 100
# 1
# 1
# 0.48854961832061067
# nan
# nan
# 100
# 1
# 1
# 0.5228758169934641
# nan
# nan
# 100
# 1
# 1
# execute
# 1
# the econometric society annual reports. report of the secretary
# ----match----the econometric society annual reports report of the secretary    0.992
# 1    1
# Salanie, Bernard     Bernard Salanie
#
#
# 28114
# execute
# 1
# a polynomial optimization approach to principal-agent problems
# ----match----a polynomial optimization approach to principal—agent problems    0.9838709677419355
# 2    2
# Renner, Philipp     Philipp Renner
#
#
# 28095
# execute
# 1
# the econometric society annual reports. report of the editors of the monograph series
# ----match----the econometric society annual reports report of the editors of the monograph series    0.9940828402366864
# 1    1
# Andrews, Donald W.K.     Donald W. K. Andrews
#
#
# 28118
# execute
# 1
# the econometric society annual reports. report of the editors 2013-2014
# ----match----the econometric society annual reports report of the editors 2013-2014    0.9929078014184397
# 1    1
# Acemoglu, Daron     Daron Acemoglu
#
#
# 28116
# execute
# 1
# homo moralis-preference evolution under incomplete information and assortative matching
# ----match----homo moralis—preference evolution under incomplete information and assortative matching    0.9885057471264368
# 6    6
# Alger, Ingela     Ingela Alger
#
#
# 28213
# 0.6896551724137931
# Rivkin, Steven G.
# Steven G. Rivkin
# 100
# 4
# 4
# execute
# 1
# on the asymptotic sizes of subset anderson-rubin and lagrange multiplier tests in linear instrumental variables regression
# ----match----on the asymptotic sizes of subset anderson—rubin and lagrange multiplier tests in linear instrumental variables regression    0.9918032786885246
# 6    6
# Guggenberger, Patrik     Patrik Guggenberger
#
#
# 28301
# execute
# 1
# a dynamic model for binary panel data with unobserved heterogeneity admitting a √n-consistent conditional estimator
# ----match----a dynamic model for binary panel data with unobserved heterogeneity admitting a $\sqrt n $ -consistent conditional estimator    0.9539748953974896
# 2    2
# Bartolucci, Francesco     Francesco Bartolucci
#
#
# 28521
# execute
# 1
# optimal mandates and the welfare cost of asymmetric information: evidence from the u.k. annuity market
# ----match----optimal mandates and the welfare cost of asymmetric information: evidence from the u. k. annuity market    0.9951219512195122
# 3    3
# Einav, Liran     Liran Einav
#
#
# 28505
# execute
# 1
# generalized utilitarianism and harsanyi's impartial observer theorem
# ----match----generalized utilitarianism and harsanyfs impartial observer theorem    0.9777777777777777
# 6    6
# Grant, Simon     Simon Grant
#
#
# 28466
# 0.5176470588235295
# Repullo, Rafael
# Rafael Repullo
# 100
# 1
# 1
# execute
# 1
# recursive methods in discounted stochastic games: an algorithm for δ→ 1 and a folk theorem
# ----match----recursive methods in discounted stochastic games: an algorithm for δ → 1 and a folk theorem    0.994475138121547
# 4    4
# Hörner, Johannes     Johannes Hörner
#
#
# 28426
# execute
# 1
# the persistent effects of peru's mining mita
# ----match----the persistent effects of peru's mining 'mita'    0.9777777777777777
# 6    6
# Dell, Melissa     Melissa Dell
#
#
# 28464
# execute
# 1
# inference in dynamic discrete choice models with serially orrelated unobserved state variables
# ----match----inference in dynamic discrete choice models with serially correlated unobserved state variables    0.9947089947089947
# 5    5
# Norets, Andriy     Andriy Norets
#
#
# 28572
# 0.7619047619047619
# Rincón-Zapatero, Juan Pablo
# Juan Pablo Rincón-Zapatero
# 100
# 1
# 1
# 0.7937743190661478
# Swensen, Anders Rygh
# Anders Rygh Swensen
# 100
# 5
# 5
# 0.9411764705882353
# Repullo, Rafael
# Rafael Repullo
# 100
# 1
# 1
# 0.7678571428571429
# Persson, Torsten
# Torsten Persson
# 100
# 6
# 6
# execute
# 1
# identifying social interactions through conditional cariance restrictions
# ----match----identifying social interactions through conditional variance restrictions    0.9863013698630136
# 3    3
# Graham, Bryan S.     Bryan S. Graham
#
#
# 28681
# 0.6029411764705882
# Hurvich, Clifford M.
# Clifford M. Hurvich
# 100
# 3
# 3
# execute
# 1
# the econometric society annual reports report of the secretary
# ----match----the econometric society annual reports: report of the secretary    0.992
# 1    1
# Repullo, Rafael     Rafael Repullo
#
#
# 28776
# 0.0915032679738562
# Dekel, Eddie
# Eddie Dekel
# 100
# 1
# 2
# execute
# 1
# decision theory applied to an instrumental variables model
# ----match----decision theory applited to an instrumental variables model    0.9914529914529915
# 3    3
# Chamberlain, Gary     Gary Chamberlain
#
#
# 28742
# 0.7373737373737373
# De Castro, Luciano I.
# Luciano I. de Castro
# 100
# 6
# 6
# 0.912
# Repullo, Rafael
# Rafael Repullo
# 100
# 1
# 1
# execute
# 1
# least squares model averaging
# ----match----leats squares model averaging    0.9655172413793104
# 4    4
# Hansen, Bruce E.     Bruce E. Hansen
#
#
# 28735
# execute
# 1
# business cycle accounting
# ----match----business cylce accounting    0.96
# 3    3
# Chari, V.V.     V. V. Chari
#
#
# 28746
# 0.8076923076923077
# Dekel, Eddie
# Eddie Dekel
# 100
# 1
# 1
# execute
# 1
# estimating semiparametric arch(∞) models by kernel smoothing methods
# ----match----estimating semiparametric arch (∞) models by kernel smoothing methods    0.9927007299270073
# 3    3
# Linton, O.     O. Linton
#
#
# 28902
# 0.2857142857142857
# nan
# nan
# 100
# 4
# 1
# execute
# 1
# the theory of global games on test: eperimental analysis of coordination games with public and private information
# ----match----the theory of global games on test: experimental analysis of coordination games with public and private information    0.9956331877729258
# 5    5
# Heinemann, Frank     Frank Heinemann
#
#
# 28967
# execute
# 1
# asymptotic normality the qmle estimator of arch in the nonstationary case
# ----match----asymptotic normality of the qmle estimator of arch in the nonstationary case    0.9798657718120806
# 2    2
# Jensen, Søren Tolver     Søren Tolver Jensen
#
#
# 29014
# 0.7186147186147186
# Jackson, Matthew O.
# Matthew O. Jackson
# 100
# 6
# 6
# execute
# 1
# bargaining without a common prior-an immediate agreement theorem
# ----match----bargaining without a common prior: an immediate agreement theorem    0.9767441860465116
# 3    3
# Yildiz, Muhamet     Muhamet Yildiz
#
#
# 29085
# execute
# 1
# heteroskedasticity-auto correlation robust standard errors using the bartlett kernel without truncation
# ----match----heteroskedasticity-autocorrelation robust standard errors using the bartlett kernel without truncation    0.9951219512195122
# 5    5
# Kiefer, Nicholas M.     Nicholas M. Kiefer
#
#
# 29166
# execute
# 1
# discrete-time approximations of the holmström-milgrom brownian-motion model of intertemporal incentive provision
# ----match----discrete-time approximations of the holmströ-milgrom brownian-motion model of intertemporal incentive provision    0.9955156950672646
# 6    6
# Hellwig, Martin F.     Martin F. Hellwig
#
#
# 29137
# execute
# 1
# ambiguity, risk, and asset returns, in continuous time
# ----match----ambiguity, risk, and asset returns in continuous time    0.9906542056074766
# 4    4
# Chen, Zengjing     Zengjing Chen
#
#
# 29175
# 0.9066666666666666
# Andrews, Donald W. K.
# Donald W. K. Andrews
# 100
# 1
# 1
# execute
# 1
# explaining investment dynamics in u.s. manufacturing: a generalized (s, s) approach
# ----match----explaining investment dynamics in u.s. manufacturing: a generalized (s,s) approach    0.9939393939393939
# 4    4
# Caballero, Ricardo J.     Ricardo J. Caballero
#
#
# 29472
# execute
# 1
# indeterminacy under constant returns to scale in multisector economies
# ----match----indeterminacy under constant retursn to scale in multisector economies    0.9857142857142858
# 6    6
# Benhabib, Jess     Jess Benhabib
#
#
# 29361
# execute
# 1
# efficiency and immmediate agreement: a reply to hart and levy
# ----match----efficiency and immediate agreement: a reply to hart and levy    0.9917355371900827
# 4    4
# Gul, Faruk     Faruk Gul
#
#
# 29478
# execute
# 1
# experience-weighted attraction learning in normal form games
# ----match----experienced-weighted attraction learning in normal form games    0.9917355371900827
# 4    4
# Camerer, Colin     Colin Camerer
#
#
# 29473
# execute
# 1
# the robustness of cointegration methods when regressors almost have unit roots
# ----match----on the robustness of cointegration methods when regressors almost have unit roots    0.9811320754716981
# 1    1
# Elliott, Graham     Graham Elliott
#
#
# 29615
# execute
# 1
# on shorrocks' reinvestigation of the sen poverty index
# ----match----on shorrock's reinvestigation of the sen poverty index    0.9814814814814815
# 5    5
# Chakravarty, Satya R.     Satya R. Chakravarty
#
#
# 29655
# execute
# 1
# edgeworth's conjecture with infinitely many commodities: l1
# ----match----edgeworth's conjecture with infinitely many commodities: l^1    0.9915966386554622
# 2    2
# Anderson, Robert M.     Robert M. Anderson
#
#
# 29693
# execute
# 1
# high breakdown point conditional dispersion estimation with application to s and p 500 daily returns volatility
# ----match----high breakdown point conditional dispersion estimation with application to s & p 500 daily returns volatility    0.9818181818181818
# 3    3
# Sakata, Shinichi     Shinichi Sakata
#
#
# 29582
# 0.8737864077669902
# Farebrother, R.W.
# R. W. Farebrother
# 100
# 6
# 6
# execute
# 1
# constistent specification testing via nonparametric series regression
# ----match----consistent specification testing via nonparametric series regression    0.9927007299270073
# 5    5
# Hong, Yongmiao     Yongmiao Hong
#
#
# 29837
# 0.9019607843137255
# Sargan, J.D.
# J. D. Sargan
# 100
# 5
# 5
# execute
# 1
# an asymptotic theory of bayesian inference for time series
# ----match----an asymtotic theory of bayesian inference for time series    0.991304347826087
# 2    2
# Phillips, Peter C. B.     Peter C. B. Phillips
#
#
# 29791
# jpe
# 0.2617801047120419
# nan
# nan
# 100
# 5
# 7
# 0.5531914893617021
# Blundell, Richard
# Blundell, Richard
# 100
# S1
# S1
# execute
# 1
# dynamic collective choice withendogenous status quo
# ----match----dynamic collective choice with endogenous status quo    0.9902912621359223
# 4    4
# Dziuda, Wioletta     Wioletta Dziuda
#
#
# 37360
# execute
# 1
# in the shadow of a giant medicare's influence on private physician payments
# ----match----in the shadow of a giant: medicare's influence on private physician payments    0.9933774834437086
# 1    1
# Clemens, Jeffrey     Jeffrey Clemens
#
#
# 37324
# execute
# 1
# economic growth: the past, the present, and the future
# ----match----economic growth: past, the present, and the future    0.9615384615384616
# 6    6
# Akcigit, Ufuk     Ufuk Akcigit
#
#
# 37240
# 0.6536585365853659
# Ashlagi, Itai
# Itai Ashlagi
# 100
# 2
# 1
# 0.2571428571428571
# List, John
# John List
# 100
# 6
# 6
# execute
# 1
# pathways to education: an integrated approach to helping at-risk high school students
# ----match----pathways to education: an integrated approach to helping at-risk high school student    0.9940828402366864
# 4    4
# Oreopoulos, Philip     Philip Oreopoulos
#
#
# 37292
# execute
# 1
# life cycle wage dynamics and labor mobility
# ----match----life cycle wage dyamics and labor mobility    0.9882352941176471
# 6    6
# Neal, Derek     Derek Neal
#
#
# 37257
# execute
# 1
# entrepreneurs,risk aversion, and dynamic firms
# ----match----entrepreneurs, risk aversion, and dynamic firms    0.989247311827957
# 5    5
# Herranz, Neus     Neus Herranz
#
#
# 37403
# execute
# 1
# (mixed) strategy in oligopoly pricin: evidence from gasoline price cycles before and under a timing regulation
# ----match----(mixed) strategy in oligopoly pricing: evidence from gasoline price cycles before and under a timing regulation    0.995475113122172
# 6    6
# Wang, Zhongmin     Zhongmin Wang
#
#
# 37660
# execute
# 1
# the reaction of consumer spending and debt to tax rebates-evidence from consumer credit data
# ----match----the reaction of consumer spending and debt to tax rebates—evidence from consumer credit data    0.9891304347826086
# 6    6
# Agarwal, Sumit     Sumit Agarwal
#
#
# 37753
# execute
# 1
# strategie ambiguity and arms proliferation
# ----match----strategic ambiguity and arms proliferation    0.9761904761904762
# 6    6
# Baliga, Sandeep     Sandeep Baliga
#
#
# 37705
# 0.8648648648648649
# Hutchinson, Kevin P.
# Kevin P. Hutchinson
# 97
# 3
# 3
# execute
# 1
# universal child care, matemal labor supply, and family well-being
# ----match----universal child care, maternal labor supply, and family well-being    0.9770992366412213
# 4    4
# Baker, Michael     Michael Baker
#
#
# 37724
# execute
# 1
# women, war and wages: the effect of female labor supply on the wage structure at midcentury
# ----match----women, war, and wages: the effect of female labor supply on the wage structure at midcentury    0.994535519125683
# 3    3
# Acemoglu, Daron     Daron Acemoglu
#
#
# 37939
# execute
# 1
# estimating life cycle labor supply tax effects
# ----match----extimating life cycle labor supply tax effects    0.9782608695652174
# 2    2
# Ziliak, James P.     James P. Ziliak
#
#
# 38277
# execute
# 1
# auctioning entry into tournaments
# ----match----auctionin entry into tournaments    0.9846153846153847
# 3    3
# Fullerton, Richard L.     Richard L. Fullerton
#
#
# 38272
# execute
# 1
# an empirical analysis of the daily labor supply of stadium vendors
# ----match----an empirical analysis of the daily labor supply of stadium venors    0.9923664122137404
# 2    2
# Oettinger, Gerald S.     Gerald S. Oettinger
#
#
# 38278
# execute
# 1
# dowry and wife's welfare: a theoretical and empirical analysis
# ----match----dowry and wife's welfare: a theotrical and empirical analysis    0.975609756097561
# 4    4
# Zhang, Junsen     Junsen Zhang
#
#
# 38263
# execute
# 1
# steady endogenous growth with population and r & d inputs growing
# ----match----steady endogenous growth with population and r. & d. inputs growing    0.9848484848484849
# 4    4
# Howitt, Peter     Peter Howitt
#
#
# 38260
# execute
# 1
# voluntary compliance with market-based environmental policy: evidence from the u.s. acid rain program
# ----match----voluntary compliance with market-based environmental policy: evidence from the u. s. acid rain program    0.9950738916256158
# 5    5
# Montero, Juan-Pablo     Juan‐Pablo Montero
#
#
# 38254
# execute
# 1
# transactions costs and nonlinear adjustment in real exchange rates: an empirical investigation
# ----match----transactions costs and nonlinear adjustment in real exchange rates; an empirical investigation    0.9893617021276596
# 4    4
# Michael, Panos     Panos Michael
#
#
# 38366
# execute
# 1
# the theory of sovereign debt and spain under philip ii
# ----match----the theory of sovering debt and spain under philip ii    0.9719626168224299
# 3    3
# Conklin, James     James Conklin
#
#
# 38317
# 0.8508771929824561
# Barber, Brad M.
# Brad M. Barber
# 100
# 5
# 5
# execute
# 1
# differential fecundity, markets, and gender roles
# ----match----differntial fecundity, markets, and gender roles    0.9896907216494846
# 2    2
# Siow, Aloysius     Aloysius Siow
#
#
# 38325
# res
# execute
# 1
# do female officers improve law enforcement quality? effects on crime reporting and domestic violence
# ----match----do female officers improve law enforcement quality?: effects on crime reporting and domestic violence    0.9950248756218906
# 5    5
# Miller, Amalia R.     AMALIA R. MILLER
#
#
# 51369
# 0.5957446808510638
# Michaillat, Pascal
# PASCAL MICHAILLAT
# 100
# 5
# 3
# 0.04040404040404041
# nan
# nan
# 100
# 3
# 1
# execute
# 1
# the (q,s,s) pricing rule
# ----match----the (q, s,s) pricing rule    0.9795918367346939
# 2    2
# Burdett, Kenneth     KENNETH BURDETT
#
#
# 51473
# execute
# 1
# one, two, many-insensitivity to group size in games with concentrated benefits and dispersed costs
# ----match----one, two, many—insensitivity to group size in games with concentrated benefits and dispersed costs    0.9897959183673469
# 3    3
# Schumacher, Heiner     HEINER SCHUMACHER
#
#
# 51537
# execute
# 1
# macroeconomic dynamics near the zlb: atale of two countries
# ...
# ----match----merchandise management accounting: a retailing experiment in marginal calculation    0.9938650306748467
# 4    4
# Heim, Peggy     Peggy Heim
#
#
# 58703
# execute
# 1
# selling expensse as a barrier to entry
# ----match----selling expense as a barrier to entry    0.9866666666666667
# 1    1
# Williamson, Oliver E.     Oliver E. Williamson
#
#
# 58742
# execute
# 1
# backward-sloping labor supply functions in dual economies — the africa case
# ----match----backward-sloping labor supply functions in dual economies--the africa case    0.9664429530201343
# 3    3
# Berg, Elliot J.     Elliot J. Berg
#
#
# 58833
# execute
# 1
# the use of adaptive expectations in stability analysis: reply
# ----match----the use of adaptive expectations in stability analysis: a reply    0.9838709677419355
# 2    2
# Nerlove, Marc     Marc Nerlove
#
#
# 58855
# 0.45098039215686275
# Hodgman, Donald R.
# Donald R. Hodgman
# 100
# 2
# 2
# execute
# 1
# credit risk and credit rationing:comment
# ----match----credit risk and credit rationing: a comment    0.963855421686747
# 2    2
# Chase, Sam B.     Sam B. Chase
#
#
# 58852
# 0.3333333333333333
# nan
# nan
# 100
# 1
# 1
# execute
# 1
# accelerated investment as a force in economic development: reply
# ----match----[accelerated investment as a force in economic development]: reply    0.9846153846153847
# 3    3
# Ellis, Howard S.     Howard S. Ellis
#
#
# 58973
# execute
# 1
# the use of adaptive expectations in stability analysis: comment
# ----match----the use of adaptive expectations in stability analysis: a comment    0.984375
# 2    2
# Mills, Edwin S.     Edwin S. Mills
#
#
# 58854
# execute
# 1
# the yugoslav investment auctions
# ----match----the yuogoslav investment auctions    0.9846153846153847
# 1    1
# Neuberger, Egon     Egon Neuberger
#
#
# 59002
# execute
# 1
# aristotle, schumpeter, and the metallist tradition
# ----match----aristotle, schumpeter, and the metalist tradition    0.98989898989899
# 4    4
# Gordon, Barry J.     Barry J. Gordon
#
#
# 58818
# 0.6432160804020101
# Samuelson, Paul A.
# Paul A. Samuelson
# 100
# 2
# 1
# execute
# 1
# the classical economists and the factory acts — a re-examination
# ----match----the classical economists and the factory acts--a re-examination    0.9606299212598425
# 2    2
# Blaug, Mark     Mark Blaug
#
#
# 59048
# 0.6067415730337079
# Schlesinger, James R.
# James R. Schlesinger
# 100
# 3
# 3
# execute
# 1
# is the income of the 'cadres' a special class of wages (a study in the light of french experience)
# ----match----is the income of the 'cadres' a special class of wages?: (a study in the light of french experience)    0.98989898989899
# 2    2
# Marchal, Jean     Jean Marchal
#
#
# 59045
# execute
# 1
# mr. wright's theory of interest: reply
# ----match----[mr. wright's theory of interest]: reply    0.9743589743589743
# 3    3
# Wright, A. Ll     A. LL. Wright
#
#
# 58975
# execute
# 1
# the effect of devaluation on the price level: further comment
# ----match----the effect of devaluation on the price level: furter comment    0.9917355371900827
# 4    4
# Hinshaw, Randall     Randall Hinshaw
#
#
# 59023
# execute
# 1
# income distribution, value judgments, and welfare: a correction
# ----match----income distribution, value judgements, and welfare: a correction    0.9921259842519685
# 2    2
# Kenen, Peter B.     Peter B. Kenen
#
#
# 59105
# 0.17543859649122806
# Davis, Richard M.
# Richard M. Davis
# 100
# 4
# 2
# execute
# 1
# competition, monopoly and countervailing power — a correction
# ----match----competition, monopoly and countervailing power: a correction    0.9752066115702479
# 3    3
# Adams, Walter     Walter Adams
#
#
# 59254
# 0.5625
# nan
# nan
# 100
# 4
# 1
# execute
# 1
# the marginal and average propensities to consume: reply
# ----match----the marginal and aerage propensities to consume: reply    0.9908256880733946
# 4    4
# Hubbard, J.C.     J. C. Hubbard
#
#
# 59185
# execute
# 1
# boisguilbert: a neglected precursor of aggregate demand theorists — comment
# ----match----boisguilbert: a neglected precursor of aggregate demand theorists: comment    0.9798657718120806
# 1    1
# Van Dyke Roberts, Hazel     Hazel Van Dyke Roberts
#
#
# 59166
# execute
# 1
# information, risk, ignorance and indeterminacy
# ----match----information, risk, ignorance, and indeterminacy    0.989247311827957
# 4    4
# Shubik, Martin     Martin Shubik
#
#
# 59240
# execute
# 1
# is group choice a part of economics? further comment
# ----match----is group choice a part of economics?: further comment    0.9904761904761905
# 4    4
# Ellis, Howard S.     Howard S. Ellis
#
#
# 59296
# execute
# 1
# on the theory of price agreements
# ----match----on the theory of price agreements 1    0.9705882352941176
# 2    2
# Brems, Hans     Hans Brems
#
#
# 59420
# execute
# 1
# collusion under the sherman act
# ----match----collusion under the sherman act 1    0.96875
# 2    2
# Kaysen, Carl     Carl Kaysen
#
#
# 59421
# execute
# 1
# oil refining: cross-elasticities of supply
# ----match----oil refining: cross-elasticities of supply 1    0.9767441860465116
# 2    2
# Manne, Alan S.     Alan S. Manne
#
#
# 59418
# 0.1702127659574468
# Bain, Joe S.
# Joe S. Bain
# 100
# 4
# 4
# 0.7388535031847133
# Isard, Walter
# Walter Isard
# 100
# 3
# 2
# execute
# 1
# currency appreciation as an anti-inflationary device
# ----match----currency appeciation as an anti-inflationary device    0.9902912621359223
# 4    4
# Hinshaw, Randall     Randall Hinshaw
#
#
# 59394
# 0.10714285714285714
# Adelman, M.A.
# M. A. Adelman
# 100
# 2
# 2
# 0.3333333333333333
# nan
# nan
# 100
# 3
# 1
# execute
# 1
# equilibrium in multi-process industries — further comments
# ----match----'equilibrium in multi-process industries': further comments    0.9572649572649573
# 3    3
# Adelman, M.A.     M. A. Adelman
#
#
# 59671
# execute
# 1
# the fallacies of lord keynes' general theory
# ----match----the fallacies of lord keynes general theory    0.9885057471264368
# 3    3
# Rueff, Jacques     Jacques Rueff
#
#
# 59619
# execute
# 1
# proportionality, divisibility, and economies of scale: two comment
# ----match----proportionality, divisibility, and economies of scale: two comments    0.9924812030075187
# 1    1
# McLeod, A.N.     A. N. McLeod
#
#
# 59540
# 0.22580645161290322
# nan
# nan
# 100
# 2
# 2
# execute
# 1
# the bullion report reexamined
# ----match----the bullion report reëxamined    0.9655172413793104
# 4    4
# Fetter, Frank Whitson     Frank Whitson Fetter
#
#
# 59830
# 0.32
# nan
# nan
# 100
# 2
# 2
# 0.3333333333333333
# nan
# nan
# 100
# 1
# 2
# 0.20689655172413793
# Maverick, Lewis A.
# Lewis A. Maverick
# 100
# 2
# 2
# 0.36666666666666664
# nan
# nan
# 100
# 1
# 2
# 0.8395061728395061
# Weintraub, Sidney
# Sidney Weintraub
# 100
# 4
# 4
# 0.32142857142857145
# Black, John D.
# John D. Black
# 100
# 2
# 2
# 0.6728971962616822
# nan
# nan
# 100
# 1
# 1
# 0.33663366336633666
# nan
# nan
# 100
# 1
# 2
# execute
# 1
# the scale of agricultural production — some corrections
# ----match----the scale of agricultural production--some corrections    0.9541284403669725
# 2    2
# Hopkins, J.A.     J. A. Hopkins
#
#
# 59979
# 0.25806451612903225
# nan
# nan
# 100
# 1
# 2
# 0.15873015873015872
# Crum, William Leonard
# William Leonard Crum
# 100
# supplement
# S1
# 0.2608695652173913
# nan
# nan
# 100
# supplement
# 1
# 0.22916666666666666
# nan
# nan
# 100
# 1
# 2
# 0.15384615384615385
# Anderson, Karl L.
# Karl L. Anderson
# 100
# 1
# 1
# 0.41509433962264153
# nan
# nan
# 100
# supplement
# 2
# 0.23333333333333334
# nan
# nan
# 100
# supplement
# 1
# execute
# 1
# sociological elements in economic thought: ii. the analytical factor view
# ----match----sociological elements in economic thought: ii. the analytical factor view^1    0.9864864864864865
# 4    4
# Parsons, Talcott     Talcott Parsons
#
#
# 60221
# execute
# 1
# dividends, interest, profits, wages, 1923-35
# ----match----dividends, interest, profits, wages, 1923-35^1    0.9777777777777777
# 4    4
# Kreps, T.J.     T. J. Kreps
#
#
# 60218
# execute
# 1
# the pure theory of consumers behavior
# ----match----the pure theory of consumer's behavior    0.9866666666666667
# 4    4
# Georgescu-Roegen, N.     N. Georgescu-Roegen
#
#
# 60156
# execute
# 1
# the old-age reserve account — a problem in government finance
# ----match----the old-age reserve account--a problem in government finance    0.9586776859504132
# 3    3
# nan    nan
#
#
# 60129
# 0.32
# nan
# nan
# 100
# 1
# 2
# execute
# 1
# british and american exchange policies: i. the british experience
# ----match----british and american exchange policies i. the british experience    0.9922480620155039
# 3    3
# Harris, S.E.     S. E. Harris
#
#
# 60287
# 0.4090909090909091
# nan
# nan
# 100
# 1
# 3
# execute
# 1
# the end of the coöperative coopers
# ----match----the end of the cooperative coopers    0.9705882352941176
# 3    3
# Virtue, G.O.     G. O. Virtue
#
#
# 60390
# 0.9230769230769231
# Chamberlin, Edward
# Edward Chamberlin
# 100
# 1
# 1
# execute
# 1
# the rôle of price in the international trade mechanism
# ----match----the role of price in the international trade mechanism    0.9814814814814815
# 4    4
# Carr, Robert M.     Robert M. Carr
#
#
# 60432
# execute
# 1
# stock dividends, large scale business, and corporate savings — a criticism
# ----match----stock dividends, large scale business, and corporate savings--a critism    0.9517241379310345
# 3    3
# Means, Gardiner C.     Gardiner C. Means
#
#
# 60445
# execute
# 1
# commercial policy and its scientific method: a reply
# ----match----commerical policy and its scientific method: a reply    0.9807692307692307
# 4    4
# Eulenburg, F.     F. Eulenburg
#
#
# 60477
# execute
# 1
# money, trade, and prices — a test of causal primacy
# ----match----money, trade, and prices--a test of causal primacy    0.9504950495049505
# 4    4
# Copeland, Morris A.     Morris A. Copeland
#
#
# 60516
# execute
# 1
# esslen's politik des auswärtigen handels
# ----match----esslen's politik des auswartigen handels    0.975
# 2    2
# Taussig, F.W.     F. W. Taussig
#
#
# 60626
# 0.5740740740740741
# Barnett, George E.
# George E. Barnett
# 100
# 3
# 1
# execute
# 1
# issues in economic theory an attempt to clarify
# ----match----issues in economic theory: an attempt to clarify    0.9894736842105263
# 3    3
# Homan, Paul T.     Paul T. Homan
#
#
# 60573
# execute
# 1
# what do statistical ' demand curves' show?1
# ----match----what do statistical 'demand curves' show?    0.9761904761904762
# 2    2
# Working, E.J.     E. J. Working
#
#
# 60622
# execute
# 1
# economics as a field of research1
# ----match----economics as a field of research    0.9846153846153847
# 1    1
# Young, Allyn A.     Allyn A. Young
#
#
# 60592
# execute
# 1
# the advantages of labor turnover an illustrative case
# ----match----the advantages of labor turnover: an illustrative case    0.9906542056074766
# 3    3
# Bezanson, Anne     Anne Bezanson
#
#
# 60577
# 0.8
# Richter, F.E.
# F. E. Richter
# 100
# 4
# 2
# 0.6203703703703703
# Haig, Robert Murray
# Robert Murray Haig
# 100
# 3
# 2
# execute
# 1
# no—par stock: its economic and legal aspects
# ----match----no-par stock: its economic and legal aspects    0.9772727272727273
# 3    3
# Bonbright, James C.     James C. Bonbright
#
#
# 60742
# execute
# 1
# the meat-packing investigation: a reply
# ----match----the meat-packaging investigation: a reply    0.975
# 3    3
# Weld, L.D.H.     L. D. H. Weld
#
#
# 60868
# execute
# 1
# coöperative production among shingle—weavers
# ----match----coperative production among shingle-weavers    0.9655172413793104
# 3    3
# Janes, George M.     George M. Janes
#
#
# 60747
# execute
# 1
# beer's history of british socialism1
# ----match----beer's history of british socialism    0.9859154929577465
# 4    4
# Feis, Herbert     Herbert Feis
#
#
# 60861
# execute
# 1
# gasoline prices as affected by interlocking stockownership and joint cost
# ----match----gasoline prices as affected by interlocking stock ownership and joint cost    0.9931972789115646
# 4    4
# Haney, Lewis H.     Lewis H. Haney
#
#
# 61027
# execute
# 1
# coöperation among the mormons
# ----match----cooperation among the mormons    0.9655172413793104
# 3    3
# Gardner, Hamilton     Hamilton Gardner
#
#
# 61038
# 0.42857142857142855
# nan
# nan
# 100
# 1
# 1
# execute
# 1
# depreciation and rate control: a rejoinder
# ----match----depreciation and rate control: rejoinder    0.975609756097561
# 2    2
# Davis, Joseph S.     Joseph S. Davis
#
#
# 61131
# 0.7272727272727273
# Young, Allyn A.
# Allyn A. Young
# 100
# 2
# 2
# execute
# 1
# fire insurance rates: problems of coöperation, classification, regulation
# ----match----fire insurance rates: problems of cooperation, classification, regulation    0.9863013698630136
# 4    4
# Riegel, Robert     Robert Riegel
#
#
# 61063
# execute
# 1
# the social point of view in economics. i
# ----match----the social point of view in economics    0.961038961038961
# 1    1
# Haney, Lewis H.     Lewis H. Haney
#
#
# 61191
# execute
# 1
# american shoemakers, 1648-1895 a sketch of industrial evolution
# ----match----american shoemakers, 1648-1895: a sketch of industrial evolution    0.9921259842519685
# 1    1
# Commons, John R.     John R. Commons
#
#
# 61374
# execute
# 1
# rent and price: ' alternative use ' and ' scarcity value '
# ----match----rent and price: 'alternative use' and 'scarcity value'    0.9642857142857143
# 1    1
# Haney, Lewis H.     Lewis H. Haney
#
#
# 61328
# execute
# 1
# railway rate theories of the interstate commerce commission. iii
# ----match----railway rate theories of the interstate commerce commission    0.959349593495935
# 3    3
# Hammond, M.B.     M. B. Hammond
#
#
# 61307
# execute
# 1
# proposals for strengthening the national banking system. i
# ----match----proposals for strengthening the national banking system    0.9734513274336283
# 2    2
# Sprague, O.M.W.     O. M. W. Sprague
#
#
# 61361
# execute
# 1
# proportions of factors—advantage and size
# ----match----proportions of factors--advantage and size    0.963855421686747
# 4    4
# Davenport, H.J.     H. J. Davenport
#
#
# 61384
# execute
# 1
# proposals for strengthening the national banking system. ii
# ----match----proposals for strengthening the national banking system    0.9649122807017544
# 4    4
# Sprague, O.M.W.     O. M. W. Sprague
#
#
# 61336
# execute
# 1
# types of american labor unions: the 'longshoremen of the great lakes
# ----match----types of american labor unions: the longshoremen of the great lakes    0.9925925925925926
# 1    1
# Commons, John R.     John R. Commons
#
#
# 61546
# execute
# 1
# types of american labor organization.—the teamsters of chicago
# ----match----types of american labor organization--the teamsters of chicago    0.967741935483871
# 3    3
# Commons, J.R.     J. R. Commons
#
#
# 61565
# execute
# 1
# types of american labor unions.—the musicians of st. louis and new york
# ----match----types of american labor unions--the musicians of st. louis and new york    0.971830985915493
# 3    3
# Commons, John R.     John R. Commons
#
#
# 61528
# 0.5
# nan
# nan
# 100
# 4
# 1
# 0.32
# nan
# nan
# 100
# 1
# 1
# 0.4
# Carver, T.N.
# T. N. Carver
# 100
# 3
# 3
# execute
# 1
# a statistical survay of italian emigration
# ----match----a statistical survey of italian emigration    0.9761904761904762
# 1    1
# Foerster, Robert F.     Robert F. Foerster
#
#
# 61417
# execute
# 1
# recent tendencies in sociology. iii
# ----match----recent tendencies in sociology iii    0.9855072463768116
# 3    3
# Ross, Edward Alsworth     Edward Alsworth Ross
#
#
# 61657
# 0.21052631578947367
# nan
# nan
# 100
# 4
# 2
# execute
# 1
# what determines the value of money?
# ----match----what determines the value of money    0.9855072463768116
# 4    4
# Conant, Charles A.     Charles A. Conant
#
#
# 61601
# execute
# 1
# recent tendencies in sociology. ii
# ----match----recent tendencies in sociology ii    0.9850746268656716
# 1    1
# Ross, Edward Alsworth     Edward Alsworth Ross
#
#
# 61684
# execute
# 1
# the birth—rate in massachusetts, 1850-90
# ----match----the birth-rate in massachusetts, 1850-90    0.975
# 3    3
# Crum, F.S.     F. S. Crum
#
#
# 61901
# execute
# 1
# a forerunner of böhm-bawerk
# ----match----a forerunner of bohm-bawerk    0.9629629629629629
# 2    2
# Mixter, C.W.     C. W. Mixter
#
#
# 61911
# execute
# 1
# levàsseur's 'l'ouvrier américain.'
# ----match----levasseur's 'l'ouvrier américain'    0.9552238805970149
# 1    1
# Cummings, John     John Cummings
#
#
# 61852
# execute
# 1
# the anglo-saxon 'township.'
# ----match----the anglo-saxon 'township'    0.9811320754716981
# 3    3
# Ashley, W.J.     W. J. Ashley
#
#
# 62024
# execute
# 1
# philosophy and political economy
# ----match----'philosophy and political economy'    0.9696969696969697
# 1    1
# Brooks, John Graham     John Graham Brooks
#
#
# 62043
# execute
# 1
# the fundamental error of 'kapital und kapitalzins.'
# ----match----the fundamental error of 'kapital und kapitalzins'    0.9900990099009901
# 3    3
# Hawley, Frederick B.     Frederick B. Hawley
#
#
# 62098
# execute
# 1
# the english trades-unions
# ----match----the english trade-unions    0.9795918367346939
# 4    4
# Cummings, Edward     Edward Cummings
#
#
# 62206
# execute
# 1
# the positive theory of capital
# ----match----'the positive theory of capital'    0.967741935483871
# 3    3
# Bonar, James     James Bonar
#
#
# 62219

# %%
for i in jid:
    print(scopus_recon[i])
# Out:
# {'found_count': 108, 'check_count': 95, 'conflict_match': [], 'check': [{'scopus_id': '10.1257/aer.107.5.716', 'Title': 'the effect of state taxes on the geographical location of top earners: evidence from star scientists', 'scopus_title': 'journal of economic perspectives', 'sim': 0.30303030303030304, 'as': 'Moretti, Enrico (7005593972)', 'p': '716', 'v': '107', 'i': '5', 'a': 'Enrico Moretti and Daniel J. Wilson', 'url': 'https://www.jstor.org/stable/44871748'}, {'scopus_id': '10.1257/aer.107.5.719', 'Title': 'the economist as plumber', 'scopus_title': 'american economic journal: applied economics', 'sim': 0.4117647058823529, 'as': 'Duflo, Esther (6602205596)', 'p': '719', 'v': '107', 'i': '5', 'a': 'Esther Duflo', 'url': 'https://www.jstor.org/stable/44250353'}, {'scopus_id': '10.1257/aer.106.6.1562', 'Title': 'hal r. varian, distinguished fellow 2015', 'scopus_title': 'erratum: optimal expectations and limited medical testing: evidence from huntington disease (american economic review (2013))', 'sim': 0.30303030303030304, 'as': nan, 'p': '1562', 'v': '106', 'i': '6', 'a': nan, 'url': 'https://www.jstor.org/stable/43956919'}, {'scopus_id': '10.1257/aer.106.5.774', 'Title': 'thomas rothenberg, distinguished fellow 2015', 'scopus_title': 'committee on the status of minority groups in the economics profession (csmgep)', 'sim': 0.34146341463414637, 'as': nan, 'p': '774', 'v': '106', 'i': '5', 'a': nan, 'url': 'https://www.jstor.org/stable/43956903'}, {'scopus_id': '10.1257/aer.106.4.1214', 'Title': 'search, liquidity, and the dynamics of house prices and construction: corrigendum', 'scopus_title': 'erratum: search, liquidity, and the dynamics of house prices and construction (american economic review (2016) 106:4 (1214-1219))', 'sim': 0.6952380952380952, 'as': 'Head, Allen (56240494400); Lloyd-Ellis, Huw (6602303699); Sun, Hongfei (55492864000)', 'p': '1214', 'v': '106', 'i': '4', 'a': 'Allen Head and Huw Lloyd-Ellis and Hongfei Sun', 'url': 'https://www.jstor.org/stable/43821490'}, {'scopus_id': '10.1257/aer.15000005', 'Title': 'proceedings of the one hundred twenty-seventh annual meeting', 'scopus_title': 'report of the secretary', 'sim': 0.3373493975903614, 'as': 'Rousseau, Peter L. (7102929822)', 'p': '671', 'v': '105', 'i': '5', 'a': 'Peter L. Rousseau and Charles E. Scott and John J. Siegfried', 'url': 'https://www.jstor.org/stable/43821964'}, {'scopus_id': '10.1257/aer.15000006', 'Title': 'proceedings of the one hundred twenty-seventh annual meeting', 'scopus_title': 'report of the treasurer', 'sim': 0.3614457831325301, 'as': 'Rousseau, Peter L. (7102929822)', 'p': '675', 'v': '105', 'i': '5', 'a': 'Peter L. Rousseau and Charles E. Scott and John J. Siegfried', 'url': 'https://www.jstor.org/stable/43821964'}, {'scopus_id': '10.1257/aer.15000010', 'Title': 'richard zeckhauser, distinguished fellow 2014', 'scopus_title': 'minutes of the meeting of the executive committee: boston, ma, january 2, 2015', 'sim': 0.2764227642276423, 'as': nan, 'p': '689', 'v': '105', 'i': '5', 'a': nan, 'url': 'https://www.jstor.org/stable/43821341'}, {'scopus_id': '10.1257/aer.15000008', 'Title': 'proceedings of the one hundred twenty-seventh annual meeting', 'scopus_title': 'dear member of the american economic association', 'sim': 0.2962962962962963, 'as': 'Rousseau, Peter L. (7102929822)', 'p': '682', 'v': '105', 'i': '5', 'a': 'Peter L. Rousseau and Charles E. Scott and John J. Siegfried', 'url': 'https://www.jstor.org/stable/43821964'}, {'scopus_id': '10.1257/aer.15000004', 'Title': 'proceedings of the one hundred twenty-seventh annual meeting', 'scopus_title': 'minutes of the annual business meeting: boston, ma, january 3, 2015', 'sim': 0.3937007874015748, 'as': 'Rousseau, Peter L. (7102929822)', 'p': '669', 'v': '105', 'i': '5', 'a': 'Peter L. Rousseau and Charles E. Scott and John J. Siegfried', 'url': 'https://www.jstor.org/stable/43821964'}, {'scopus_id': '10.1257/aer.p20151059', 'Title': 'yes, r > g. so what?', 'scopus_title': 'yes, ...
# {'found_count': 35, 'check_count': 28, 'conflict_match': [], 'check': [{'scopus_id': '10.3982/ECTA861REF', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports econometrica referees 2016-2017', 'sim': 0.460431654676259, 'as': nan, 'p': '373', 'v': '86', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44956002'}, {'scopus_id': '10.3982/ECTA871TREAS', 'Title': 'the econometric society annual reports: econometrica referees 2017-2018', 'scopus_title': 'the econometric society annual reports report of the treasurer', 'sim': 0.6917293233082706, 'as': nan, 'p': '359', 'v': '87', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/45172313'}, {'scopus_id': '10.3982/ECTA861SEC', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports report of the secretary', 'sim': 0.48854961832061067, 'as': nan, 'p': '355', 'v': '86', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44956002'}, {'scopus_id': '10.3982/ECTA861EDS', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports report of the editors 2016-2017', 'sim': 0.4172661870503597, 'as': nan, 'p': '369', 'v': '86', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44956002'}, {'scopus_id': '10.3982/ECTA861MONO', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports report of the editors of the monograph series', 'sim': 0.5228758169934641, 'as': nan, 'p': '385', 'v': '86', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44956002'}, {'scopus_id': '10.3982/ECTA871SEC', 'Title': 'the econometric society annual reports: econometrica referees 2017-2018', 'scopus_title': 'the econometric society annual reports report of the secretary', 'sim': 0.6766917293233082, 'as': nan, 'p': '349', 'v': '87', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/45172313'}, {'scopus_id': '10.3982/ECTA861TREAS', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports report of the treasurer', 'sim': 0.44274809160305345, 'as': nan, 'p': '363', 'v': '86', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44956002'}, {'scopus_id': '10.3982/ECTA851REF', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports econometrica referees 2015-2016', 'sim': 0.460431654676259, 'as': nan, 'p': '333', 'v': '85', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44155426'}, {'scopus_id': '10.3982/ECTA851EDS', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports report of the editors 2015-2016', 'sim': 0.4172661870503597, 'as': nan, 'p': '329', 'v': '85', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44155426'}, {'scopus_id': '10.3982/ECTA851TREAS', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports report of the treasurer', 'sim': 0.44274809160305345, 'as': nan, 'p': '323', 'v': '85', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44155426'}, {'scopus_id': '10.3982/ECTA851SEC', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports report of the secretary', 'sim': 0.48854961832061067, 'as': nan, 'p': '315', 'v': '85', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/44155426'}, {'scopus_id': '10.3982/ECTA851MONO', 'Title': 'submission of manuscripts to the econometric society monograph series', 'scopus_title': 'the econometric society annual reports report of the editors of the monograph series', 'sim': 0. ...
# {'found_count': 20, 'check_count': 6, 'conflict_match': [], 'check': [{'scopus_id': '10.1086/709252', 'Title': 'quantifying the life-cycle benefits of an influential early-childhood program', 'scopus_title': 'erratum: ceo behavior and firm performance (journal of political economy 128, 4 (2020): 1325-1369, 10.1086/705331)', 'sim': 0.2617801047120419, 'as': nan, 'p': '2017', 'v': '128', 'i': '5', 'a': nan, 'url': 'https://doi.org/10.1086/705718'}, {'scopus_id': '10.1086/705489', 'Title': 'children, time allocation, and consumption insurance', 'scopus_title': 'erratum: children, time allocation, and consumption insurance (journal of political economy, (2018) 126, s1, (s73-s115), 10.1086/698752)', 'sim': 0.5531914893617021, 'as': 'Blundell, Richard (57189228854); Pistaferri, Luigi (6603660517); Saporta-Eksten, Itay (55651450700)', 'p': '2559', 'v': '126', 'i': 'S1', 'a': 'Blundell, Richard and Pistaferri, Luigi and Saporta-Eksten, Itay', 'url': 'https://doi.org/10.1086/698752'}, {'scopus_id': '10.1086/712589', 'Title': 'unbalanced random matching markets: the stark effect of competition', 'scopus_title': 'erratum: unbalanced random matching markets: the stark effect of competition (journal of political economy, (2017) 125(1), 10.1086/689869)', 'sim': 0.6536585365853659, 'as': 'Ashlagi, Itai (16232545100); Kanoria, Yash (24781164400); Leshno, Jacob D. (41661503100)', 'p': '646', 'v': '129', 'i': '2', 'a': 'Itai Ashlagi and Yash Kanoria and Jacob D. Leshno', 'url': 'https://www.jstor.org/stable/26549926'}, {'scopus_id': '10.1086/694751', 'Title': 'experimental economics in the journal of political economy', 'scopus_title': 'introduction', 'sim': 0.2571428571428571, 'as': 'List, John (26643272500); Uhlig, Harald (7004612674)', 'p': '1723', 'v': '125', 'i': '6', 'a': 'John List', 'url': 'https://www.jstor.org/stable/26550486'}, {'scopus_id': '10.1086/518810', 'Title': 'crime on the court: a correction', 'scopus_title': 'comments: crime on the court: a correction', 'sim': 0.8648648648648649, 'as': 'Hutchinson, Kevin P. (19337226500); Yates, Andrew J. (7202620663)', 'p': '515', 'v': '115', 'i': '3', 'a': 'Kevin\xa0P. Hutchinson and Andrew\xa0J. Yates', 'url': 'https://www.jstor.org/stable/10.1086/518810'}, {'scopus_id': '10.1086/262053', 'Title': 'product reliability and firm value: the experience of american and japanese automakers, 1973-1992', 'scopus_title': 'confirmations and contradictions: product reliability and firm value: the experience of american and japanese automakers, 1973-1992', 'sim': 0.8508771929824561, 'as': 'Barber, Brad M. (7102896501); Darrough, Masako N. (6602529908)', 'p': '1084', 'v': '104', 'i': '5', 'a': 'Brad M. Barber and Masako N. Darrough', 'url': 'https://www.jstor.org/stable/2138953'}]}
# {'found_count': 131, 'check_count': 20, 'conflict_match': [], 'check': [{'scopus_id': '10.1093/restud/rdy067', 'Title': 'optimal public expenditure with inefficient unemployment', 'scopus_title': 'corrigendum: optimal public expenditure with inefficient unemployment (review of economic studies (2018) doi: 10.1093/restud/rdy030)', 'sim': 0.5957446808510638, 'as': 'Michaillat, Pascal (57215923587); Saez, Emmanuel (7004587587)', 'p': '2284', 'v': '86', 'i': '5', 'a': 'PASCAL MICHAILLAT and EMMANUEL SAEZ', 'url': 'https://www.jstor.org/stable/26755516'}, {'scopus_id': '10.1093/restud/rdx072', 'Title': 'back matter', 'scopus_title': 'erratum: stagnation traps [review of economic studies (2017)] doi: 10.1093/restud/rdx063', 'sim': 0.04040404040404041, 'as': nan, 'p': '1936', 'v': '85', 'i': '3', 'a': nan, 'url': 'https://www.jstor.org/stable/26543898'}, {'scopus_id': '10.1111/j.1467-937X.2008.00505.x', 'Title': 'market size, trade, and productivity', 'scopus_title': 'erratum: market size, trade, and productivity (review of economic studies vol. 75 (1) 10.111/j1467-937x.2007.00463.x)', 'sim': 0.47058823529411764, 'as': 'Melitz, Marc J. (57204379078); Ottaviano, Gainmarco I.P. (55945006500)', 'p': '985', 'v': '75', 'i': '3', 'a': 'Marc J. Melitz and Giancarlo I. P. Ottaviano', 'url': 'https://www.jstor.org/stable/4626196'}, {'scopus_id': '10.1111/j.1467-937X.2007.00477.x', 'Title': 'corrigendum: consistent testing for stochastic dominance under general sampling schemes', 'scopus_title': "erratum: consistent testing for stochastic dominance under general sampling schemes' (the review of economic studies vol. 72 (735-765) 10.1111/j.1467-937x.2005.00350.x)", 'sim': 0.6274509803921569, 'as': nan, 'p': '333', 'v': '75', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/4626198'}, {'scopus_id': '10.2307/2297936', 'Title': 'volume information', 'scopus_title': 'variable returns to scale, non-uniqueness of equilibrium and the gains from international trade (volume 58(4), no. 196, july 1991, pages 807-816)', 'sim': 0.12269938650306748, 'as': nan, 'p': '807', 'v': '58', 'i': '4', 'a': nan, 'url': 'https://www.jstor.org/stable/2297938'}, {'scopus_id': '10.2307/2297507', 'Title': 'volume information', 'scopus_title': 'erratum', 'sim': 0.32, 'as': nan, 'p': '132', 'v': '56', 'i': '4', 'a': nan, 'url': 'https://www.jstor.org/stable/2297493'}, {'scopus_id': '10.2307/restud/56.4.475-a', 'Title': 'front matter', 'scopus_title': 'review of economic studies travel fund', 'sim': 0.28, 'as': nan, 'p': '475', 'v': '56', 'i': '4', 'a': nan, 'url': 'https://www.jstor.org/stable/2297745'}, {'scopus_id': '10.2307/2297726', 'Title': 'back matter', 'scopus_title': 'erratum', 'sim': 0.2222222222222222, 'as': nan, 'p': '128', 'v': '53', 'i': '5', 'a': nan, 'url': 'https://www.jstor.org/stable/2297599'}, {'scopus_id': '10.2307/2296897', 'Title': 'monopoly, non-linear pricing and imperfect information: the insurance market', 'scopus_title': 'symposium on economics of information: introduction', 'sim': 0.3937007874015748, 'as': 'Stiglitz, Joseph E. (57208457063)', 'p': '393', 'v': '44', 'i': '3', 'a': 'Joseph E. Stiglitz', 'url': 'https://www.jstor.org/stable/2296899'}, {'scopus_id': '10.2307/restud/37.2.260', 'Title': 'a simple method for estimating demand systems under separable utility assumptions', 'scopus_title': 'errata', 'sim': 0.13793103448275862, 'as': 'Byron, R.P. (6604003262)', 'p': '260', 'v': '37', 'i': '2', 'a': 'R. P. Byron', 'url': 'https://www.jstor.org/stable/2296418'}, {'scopus_id': '10.2307/2295911', 'Title': 'corrections: a reply to professor chang', 'scopus_title': 'corrections', 'sim': 0.44, 'as': nan, 'p': '220', 'v': '31', 'i': '3', 'a': nan, 'url': 'https://www.jstor.org/stable/2295913'}, {'scopus_id': '10.2307/2296201', 'Title': 'volume information', 'scopus_title': 'correction', 'sim': 0.42857142857142855, 'as': nan, 'p': '168', 'v': '31', 'i': '2', 'a': nan, 'url': 'https://www.jstor.org/stable/2295895'}, {'scopus_id': '10.2307/229 ...
# {'found_count': 176, 'check_count': 46, 'conflict_match': [], 'check': [{'scopus_id': '10.2307/1882397', 'Title': 'volume information', 'scopus_title': 'erratum', 'sim': 0.32, 'as': nan, 'p': '363', 'v': '96', 'i': '2', 'a': nan, 'url': 'https://www.jstor.org/stable/2936135'}, {'scopus_id': '10.2307/1885880', 'Title': "correcting the ricardo error spotted in harry johnson's maiden paper", 'scopus_title': 'the quarterly journal of economics', 'sim': 0.35294117647058826, 'as': 'Samuelson, Paul A. (7004920936)', 'p': '519', 'v': '91', 'i': '4', 'a': 'Paul A. Samuelson', 'url': 'https://www.jstor.org/stable/1885880'}, {'scopus_id': '10.2307/1882047', 'Title': 'comment', 'scopus_title': 'symposium: economics of the new left comment', 'sim': 0.27450980392156865, 'as': 'Bach, G.L. (56952266100)', 'p': '632', 'v': '86', 'i': '4', 'a': 'G. L. Bach', 'url': 'https://www.jstor.org/stable/1882047'}, {'scopus_id': '10.2307/1881845', 'Title': "swaps and roosa bonds as an index of the cost of cooperation in the 'crisis zone'", 'scopus_title': 'rejoinder', 'sim': 0.15555555555555556, 'as': 'Kain, John F. (7006030437)', 'p': '161', 'v': '85', 'i': '1', 'a': 'John H. Makin', 'url': 'https://www.jstor.org/stable/1880711'}, {'scopus_id': '10.2307/1882275', 'Title': '[the marginalist principle in a discrete production model under uncertain demand]: rejoinder', 'scopus_title': 'per capita consumption and growth: rejoinder', 'sim': 0.4117647058823529, 'as': 'Fei, J.C.H. (55830794500)', 'p': '710', 'v': '85', 'i': '4', 'a': 'J. C. H. Fei', 'url': 'https://www.jstor.org/stable/1882275'}, {'scopus_id': '10.2307/1880737', 'Title': 'volume information', 'scopus_title': 'correction to: effects of the threats of losses on duopoly bargaining (volume lxxx may 1966 page 309)', 'sim': 0.15126050420168066, 'as': nan, 'p': '492', 'v': '80', 'i': '3', 'a': nan, 'url': 'https://www.jstor.org/stable/1880574'}, {'scopus_id': '10.2307/1880519', 'Title': 'the rationality of official intervention in the forward exchange market: further comment', 'scopus_title': 'further comment', 'sim': 0.2912621359223301, 'as': 'Ward, Richard (57659068800)', 'p': '148', 'v': '79', 'i': '1', 'a': 'Richard Ward', 'url': 'https://www.jstor.org/stable/1880519'}, {'scopus_id': '10.2307/1879333', 'Title': '[the social rate of discount and the optimal rate of investment]: further comment', 'scopus_title': 'further comment', 'sim': 0.3125, 'as': 'Lind, Robert C. (57188781987)', 'p': '336', 'v': '78', 'i': '2', 'a': 'Robert C. Lind', 'url': 'https://www.jstor.org/stable/1879333'}, {'scopus_id': '10.2307/1884207', 'Title': 'credit risk and credit rationing: a reply', 'scopus_title': 'the use of adaptive expectations in stability analysis: reply', 'sim': 0.45098039215686275, 'as': 'Hodgman, Donald R. (57188779647)', 'p': '327', 'v': '75', 'i': '2', 'a': 'Donald R. Hodgman', 'url': 'https://www.jstor.org/stable/1884207'}, {'scopus_id': '10.2307/1884141', 'Title': 'volume information', 'scopus_title': 'errata', 'sim': 0.3333333333333333, 'as': nan, 'p': '162', 'v': '74', 'i': '1', 'a': nan, 'url': 'https://www.jstor.org/stable/1884129'}, {'scopus_id': '10.2307/1883721', 'Title': 'a modern treatment of the ricardian economy: i. the pricing of goods and of labor and land services', 'scopus_title': 'a modern treatment of the ricardian economy: ii. capital and interest aspects of the pricing process', 'sim': 0.6432160804020101, 'as': 'Samuelson, Paul A. (7004920936)', 'p': '217', 'v': '73', 'i': '2', 'a': 'Paul A. Samuelson', 'url': 'https://www.jstor.org/stable/1883824'}, {'scopus_id': '10.2307/1880614', 'Title': 'the ebb tide of capitalism?', 'scopus_title': "the ebb tide of capitalism?: schumpeter's prophecy re-examined", 'sim': 0.6067415730337079, 'as': 'Schlesinger, James R. (57012754800); Phillips, Almarin (56238598100)', 'p': '448', 'v': '73', 'i': '3', 'a': 'James R. Schlesinger and Almarin Phillips', 'url': 'https://www.jstor.org/stable/1880614'}, {'scopus_id': '10.2307/1884314', 'Title': 'a  ...

# %%
content=['Article', 'Comment', 'Reply', 'Rejoinder']
content_ex=['MISC','Discussion','Review', 'Review2']

# %%
match_summary=[]
for i in jid:
    sids=list(merged[merged['jid']==i]['scopus_id'].unique())
    sids_nrm=list(merged[(merged['jid']==i)&(merged['year'].isin(year_range)==True)&(merged['content_type'].isin(content)==True)]['scopus_id'].unique())
    nrm_merged=merged[(merged['jid']==i)&(merged['content_type'].isin(content)==True)&(merged['year'].isin(year_range)==True)].shape[0]
    
    approx=sum(merged[merged['jid']==i]["scopus_indicator"])


    temp=scopus[(scopus["scopus_id"].isin(sids)==False)&(scopus["scopus_jid"]==i)].reset_index(drop=True)
    scopus_mis[i]=temp
    
    result=len(sids)*100/scopus[(scopus['scopus_jid']==i)].shape[0]
    result2=len(sids_nrm)*100/nrm_merged

    match_summary.append({
        "journal": i,
        # "total articles to 2020": merged[merged['jid']==i].shape[0],
        "articles on scopus": scopus[(scopus['scopus_jid']==i)].shape[0],
        "exact matches on title and year": len(sids)-approx,
        "approx matches on title, exact year+issue": approx,
        "unmatched scopus articles": temp.shape[0],
        "match %": f"{result:.2f}",
        "Non-MISC + Non-Rev + post 1940": nrm_merged,
        "Non-MISC + Non-Rev + post 1940 matches": len(sids_nrm),
        "NMR-post-1940 match %": f"{result2:.2f}",
        # "unmatched scopus articles post 1940": temp[temp['scopus_year'].isin(year_range)==True].shape[0],
    })
    # cids=cleaned['title'].unique()
    # cids.sort()

summary=pd.DataFrame(match_summary)
summary.to_csv("011_scopus_match_summary.csv", index=False)

# %%
merged.to_pickle("011_merged_proc_scopus_inception_2020.pkl")

# %%
sum(summary['Non-MISC + Non-Rev + post 1940 matches'])/sum(summary['Non-MISC + Non-Rev + post 1940'])
# Out:
# 0.43311720698254363

# %%
# sids=list(merged['scopus_id'].unique())
# print(len(sids))
# temp=scopus[(scopus["scopus_id"].isin(sids)==False)&(scopus["scopus_jid"]=='qje')&(scopus["scopus_year"].isin(ex_years)==False)].reset_index(drop=True)
# print(temp.shape)
# print(res_scopus.shape)

# %%
# for i in temp.sort_values(by=['scopus_volume']).index:
#     print(str(i)+' '+str(temp.loc[i,'scopus_year'])+' '+str(temp.loc[i,'scopus_volume'])+' '+temp.loc[i,'scopus_issue']+'  '+temp.loc[i,'scopus_page_start']+ '   '+temp.loc[i,'scopus_title']+ '   '+temp.loc[i,'scopus_id']+ '   '+str(temp.loc[i, 'scopus_author_full_names']))

# %%
# url='https://www.jstor.org/stable/2296392'
# sc_id=17
# print(merged.loc[merged['URL']==url,'title']==temp.loc[sc_id,'scopus_title'])
# print(merged.loc[merged['URL']==url,'title'].values[0])
# print(merged.loc[merged['URL']==url,'author'].values[0])
# print(merged.loc[merged['URL']==url,'year'].values[0])
# print(merged.loc[merged['URL']==url,'scopus_title'].values[0])
# print()

# print(temp.loc[sc_id,'scopus_title'])
# print(temp.loc[sc_id,'scopus_id'])
# print(temp.loc[sc_id,'scopus_year'])
# print(temp.loc[sc_id,'scopus_author_full_names'])
# print(temp.loc[sc_id,'scopus_affiliations'])
# print(temp.loc[sc_id,'scopus_references'])

# print(type(merged.loc[merged['URL']==url,'year'].values[0]))
# print(type(temp.loc[sc_id,'scopus_title'])) 
# print(type(temp.loc[sc_id,'scopus_year'])) 

# # {'scopus_id':'10.1093/restud/rdv008','Year':'2015'}
# # {'scopus_id':'10.2307/2967420','Title':'The Power of Undervalued Currency: A Methodological Comment'}
# # {'scopus_id':'','Title':'[Complementarity and Interrelations of Shifts in Demand]: A Comment'}
# # {'scopus_id':'10.2307/2295860','Title':'[A Note on Kaldor's `Speculation and Economic Stability']: A Comment'}

# #{'scopus_id':'10.2307/2296500', 'Title':'the existence of optimal distributed lags'}

# {'scopus_id':'10.2307/2296392', 'Title': "correction to 'on optimal development in a multi-sector economy'"}
# {'URL':'https://www.jstor.org/stable/2296392', 'author':'D. Gale'}
# {'scopus_id':'10.1093/restud/rdt040','Title':'RETRACTED: Growing up in a Recession'}
